# %% [markdown]
# Nama : Sinta Bella
# Nim : 09011181722072
# Kelas : SK5B

# %% [markdown]
# <b> Sumber : Saintia Matematika <b>
# [Vol. 1, No 6 (2013),pp.543-555]
#
# # ANALISIS TINGKAT KEPUASAN KONSUMEN BERDASARKAN PELAYANAN, HARGA DAN KUALITAS MAKANAN MENGGUNAKAN FUZZY MAMDANI

# %% [markdown]
# <center> <b> <font size="5"><font color"Green">HIMPUNAN KABUR</font></font> <b> </center>
#
# |<font color="Green"> Nama Fungsi |<font color="Blue"> Variabel |<font color="Red"> Semesta Pembicaraan |
# |---------------------------------------------------------------------------------------------|
# |<center> Input </center>| Tingkat Pelayanan <br/> Tingkat Harga <br/> Tingkat Kualitas Makanan <br/> | |1-10 <br/> 1-10 <br/> 1-10 <br/> 1-10 |
# |<center> Output </center>| Tingkat Kepuasan | |1-10|

# %% [markdown]
# <center> <b> <font size="5"><font color"Green">HIMPUNAN FUZZY</font></font> <b> </center>
#
# |<font color="Green"> VARIABEL |<font color="Blue"> HIMPUNAN FUZZY |<font color="Red"> DOMAIN |
# |---------------------------------------------------------------------------------------------|
# |Tingkat Pelayanan|Sangat Tidak Baik <br/> Tidak Baik <br/> Cukup Baik <br/> Baik <br/>| |1 4 <br/> 3 6 <br/> 5 8 <br/> 7 10 |
# |Tingkat Harga|Sangat Mahal <br/> Tidak Mahal <br/> Cukup Mahal <br/> Murah <br/>| |1 4 <br/> 3 6 <br/> 5 8 <br/> 7 10 |
# |Tingkat Kualitas Makanan|Sangat Tidak Berkualitas <br/> Tidak Berkualitas <br/> Cukup Berkualitas <br/> Berkualitas <br/>| |1 4 <br/> 3 6 <br/> 5 8 <br/> 7 10 |
# |Tingkat Kepuasan|Sangat Tidak Puas <br/> Tidak Puas <br/> Cukup Puas <br/> Puas <br/>| |1 4 <br/> 3 6 <br/> 5 8 <br/> 7 10 |

# %% [markdown]
# Abstrak: Dalam kondisi persaingan yang ketat, hal utama yang harus diprioritaskan oleh perusahaan adalah kepuasan konsumen agar dapat bertahan, bersaing dan menguasai pasar. Untuk mengukur kepuasan konsumen terdapat berbagai hal yang harus diperhatikan tidak hanya pelayanan dan harga, kualitas produk juga sangat berpengaruh. Pengaruh tingkat pelayanan, harga serta kualitas makanan terhadap kepuasan konsumen di CFC dianalisis menggunakan fuzzy Mamdani dengan bantuan software toolbox mathlab. Perancangan sistem untuk mendapatkan output dilakukan dalam beberapa tahap yaitu: pembentukan himpunan fuzzy, aplikasi fungsi implikasi (pembentukan aturan fuzzy), komposisi aturan fuzzy, penegasan (defuzziﬁkasi). Dari hasil penelitian yang telah dilakukan diperoleh input terdiri dari tingkat pelayanan diperoleh bilangan riil 5,5 dengan domain [5 8] yang artinya variabel tingkat pelayanan cukup baik, tingkat harga makanan dengan bilangan riil 5,5 dengan domain [5 8] yang artinya tingkat harga makanan cukup murah, tingkat kualitas makanan diperoleh bilangan riil 5,5 dengan domain [5 8] yang artinya tingkat kualitas makanan cukup berkualitas. Output yang diperoleh yaitu tingkat kepuasan konsumen dengan bilangan riil 6,63 yang artinya konsumen merasa cukup puas dengan pelayanan dan harga serta kualitas makanan yang diberikan Restoran cepat saji CFC.

# %%
import numpy as np # untuk memasukan library numpy
import skfuzzy as fz # untuk memasukan library fuzzy
from skfuzzy import control as ctrl # mengimport library fuzzy dari tipe control

# %%
Tipe = ctrl.Antecedent(np.arange(1,12,1),'Tingkat Pelayanan') # sebagai variabel input tingkat perlayanan diawali dengan 1 akhir 12 dan rentang 1 
Tiha = ctrl.Antecedent(np.arange(1,12,1),'Tingkat Harga') # sebagai variabel input tingkat harga diawali dengan 1 akhir 12 dan rentang 1
Kuma = ctrl.Antecedent(np.arange(1,12,1),'Kualitas Makanan') # sebagai variabel input kualitas makanan diawali dengan 1 akhir 12 dan rentang 1
Tike = ctrl.Consequent(np.arange(1,12,1),'Tingkat Kepuasan') # sebagai variabel output tingkat kepuasan diawali dengan 1 akhir 12 dan rentang 1

# %% [markdown]
# # Persamaan Tipe Pelayanan
#
# 1. $Tipe[Sangat Tidak Baik] =
# \left\{
#         \begin{array}{12}
#             {4-x \over 4-2} & \mbox { ; }  2 \leq x \leq 4 \\
#             0 & \mbox { ; }  x \geq 4
#         \end{array}
# \right.$
#
#
#
# 2. $Tipe[Tidak Baik] =
# \left\{
#         \begin{array}{12}
#             0 & \mbox { ; } x \leq 3  Or   x\geq 6 \\
#             {x-3 \over 4-3} & \mbox { ; }  3 \leq x \leq 4 \\
#             6-x \over 6-5 & \mbox { ; }  3 \leq x \leq 4
#         \end{array}
# \right.$
#
#
# 3.  $Tipe[Cukup Baik] =
# \left\{
#         \begin{array}{12}
#             0 & \mbox { ; } x \leq 5  Or  x\geq 8 \\
#             {x-5 \over 6-5} & \mbox { ; }  5 \leq x \leq 6 \\
#             8-x \over 8-7 & \mbox { ; }  x \geq 8
#         \end{array}
# \right.$
#
#
# 4. $Tipe[Baik] =
# \left\{
#         \begin{array}{12}
#             0 & \mbox { ; } x \leq 7   \\
#             {x-7 \over 8-7} & \mbox { ; }  7 \leq x \leq 8 \\
#             1 & \mbox { ; } x \geq 10
#         \end{array}
# \right.$

# %%
Tipe['STB']=fz.trapmf(Tipe.universe,[0,0,2,4]) # berfungsi untuk memplot grafik dalam bentuk trapesium dengan range angka (1,1,2,4)
Tipe['TB']=fz.trapmf(Tipe.universe,[3,4,5,6]) # berfungsi untuk memplot grafik dalam bentuk trapesium dengan range angka (3,4,5,6)
Tipe['CB']=fz.trapmf(Tipe.universe,[5,6,7,8]) # berfungsi untuk memplot grafik dalam bentuk trapesium dengan range angka (5,6,7,8)
Tipe['B']=fz.trapmf(Tipe.universe,[7,9,12,12]) # berfungsi untuk memplot grafik dalam bentuk trapesium dengan range angka (7,9,12,12)
Tipe.view()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# # Persamaan Tingkat Harga
#
# 1. $Tiha[Sangat Mahal] =
# \left\{
#         \begin{array}{12}
#             {4-x \over 4-2} & \mbox { ; }  2 \leq x \leq 4 \\
#             0 & \mbox { ; }  x \geq 4
#         \end{array}
# \right.$
#
#
#
# 2. $Tiha[Mahal] =
# \left\{
#         \begin{array}{12}
#             0 & \mbox { ; } x \leq 3  Or   x\geq 6 \\
#             {x-3 \over 4-3} & \mbox { ; }  3 \leq x \leq 4 \\
#             6-x \over 6-5 & \mbox { ; }  3 \leq x \leq 4
#         \end{array}
# \right.$
#
#
# 3.  $Tiha[Cukup Mahal] =
# \left\{
#         \begin{array}{12}
#             0 & \mbox { ; } x \leq 5  Or  x\geq 8 \\
#             {x-5 \over 6-5} & \mbox { ; }  5 \leq x \leq 6 \\
#             8-x \over 8-7 & \mbox { ; }  x \geq 8
#         \end{array}
# \right.$
#
#
# 4. $Tiha[Murah] =
# \left\{
#         \begin{array}{12}
#             0 & \mbox { ; } x \leq 7   \\
#             {x-7 \over 8-7} & \mbox { ; }  7 \leq x \leq 8 \\
#             1 & \mbox { ; } x \geq 10
#         \end{array}
# \right.$

# %%
Tiha['SML']=fz.trapmf(Tiha.universe,[1,1,2,4]) # berfungsi untuk memplot grafik dalam bentuk trapesium dengan range angka (1,1,2,4) 
Tiha['ML']=fz.trapmf(Tiha.universe,[3,4,5,6]) # berfungsi untuk memplot grafik dalam bentuk trapesium dengan range angka (3,4,5,6)
Tiha['CM']=fz.trapmf(Tiha.universe,[5,6,7,8]) # berfungsi untuk memplot grafik dalam bentuk trapesium dengan range angka (5,6,7,8)
Tiha['MRH']=fz.trapmf(Tiha.universe,[7,9,12,12]) # berfungsi untuk memplot grafik dalam bentuk trapesium dengan range angka (7,9,12,12)
Tiha.view()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# # Persamaan Kualitas Makanan
#
# 1. $Kuma[Sangat Tidak Berkualitas] =
# \left\{
#         \begin{array}{12}
#             {4-x \over 4-2} & \mbox { ; }  2 \leq x \leq 4 \\
#             0 & \mbox { ; }  x \geq 4
#         \end{array}
# \right.$
#
#
#
# 2. $Kuma[Tidak Berkualitas] =
# \left\{
#         \begin{array}{12}
#             0 & \mbox { ; } x \leq 3  Or   x\geq 6 \\
#             {x-3 \over 4-3} & \mbox { ; }  3 \leq x \leq 4 \\
#             6-x \over 6-5 & \mbox { ; }  3 \leq x \leq 4
#         \end{array}
# \right.$
#
#
# 3.  $Kuma[Cukup Berkualitas] =
# \left\{
#         \begin{array}{12}
#             0 & \mbox { ; } x \leq 5  Or  x\geq 8 \\
#             {x-5 \over 6-5} & \mbox { ; }  5 \leq x \leq 6 \\
#             8-x \over 8-7 & \mbox { ; }  x \geq 8
#         \end{array}
# \right.$
#
#
# 4. $Kuma[Berkualitas] =
# \left\{
#         \begin{array}{12}
#             0 & \mbox { ; } x \leq 7   \\
#             {x-7 \over 8-7} & \mbox { ; }  7 \leq x \leq 8 \\
#             1 & \mbox { ; } x \geq 10
#         \end{array}
# \right.$

# %%
Kuma['STBR']=fz.trapmf(Kuma.universe,[0,0,2,4]) # berfungsi untuk memplot grafik dalam bentuk trapesium dengan range angka (1,1,2,4)
Kuma['TBR']=fz.trapmf(Kuma.universe,[3,4,5,6]) # berfungsi untuk memplot grafik dalam bentuk trapesium dengan range angka (3,4,5,6)
Kuma['CBR']=fz.trapmf(Kuma.universe,[5,6,7,8]) # berfungsi untuk memplot grafik dalam bentuk trapesium dengan range angka (5,6,7,8)
Kuma['BR']=fz.trapmf(Kuma.universe,[7,9,12,12]) # berfungsi untuk memplot grafik dalam bentuk trapesium dengan range (7,9,12,12)
Kuma.view()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# # Persamaan Tingkat Kepuasan
#
# 1. $Tike[Sangat Tidak Puas] =
# \left\{
#         \begin{array}{12}
#             {4-x \over 4-2} & \mbox { ; }  2 \leq x \leq 4 \\
#             0 & \mbox { ; }  x \geq 4
#         \end{array}
# \right.$
#
#
#
# 2. $Tike[Tidak Puas] =
# \left\{
#         \begin{array}{12}
#             0 & \mbox { ; } x \leq 3  Or   x\geq 6 \\
#             {x-3 \over 4-3} & \mbox { ; }  3 \leq x \leq 4 \\
#             6-x \over 6-5 & \mbox { ; }  3 \leq x \leq 4
#         \end{array}
# \right.$
#
#
# 3.  $Tike[Cukup Puas] =
# \left\{
#         \begin{array}{12}
#             0 & \mbox { ; } x \leq 5  Or  x\geq 8 \\
#             {x-5 \over 6-5} & \mbox { ; }  5 \leq x \leq 6 \\
#             8-x \over 8-7 & \mbox { ; }  x \geq 8
#         \end{array}
# \right.$
#
#
# 4. $Tike[Puas] =
# \left\{
#         \begin{array}{12}
#             0 & \mbox { ; } x \leq 7   \\
#             {x-7 \over 8-7} & \mbox { ; }  7 \leq x \leq 8 \\
#             1 & \mbox { ; } x \geq 10
#         \end{array}
# \right.$

# %%
Tike['STP']=fz.trapmf(Tike.universe,[0,0,2,4]) # berfungsi untuk memplot grafik dalam bentuk trapesium dengan range angka (1,1,2,4)
Tike['TP']=fz.trapmf(Tike.universe,[3,4,5,6]) # berfungsi untuk memplot grafik dalam bentuk trapesium dengan range (3,4,5,6)
Tike['CP']=fz.trapmf(Tike.universe,[5,6,7,8]) # berfungsi untuk memplot grafik dalam bentuk trapesium dengan range (5,6,7,8)
Tike['P']=fz.trapmf(Tike.universe,[7,9,12,12]) # berfungsi untuk memplot grafik dalam bentuk trapesium dengan range (7,9,12,12)
Tike.view()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
Rb1 = ctrl.Rule (Tipe ['STB'] & Tiha ['SML'] & Kuma ['STBR'] , Tike ['STP'])
Rb2 = ctrl.Rule (Tipe ['STB'] & Tiha ['SML'] & Kuma ['TBR'] , Tike ['STP'])
Rb3 = ctrl.Rule (Tipe ['STB'] & Tiha ['SML'] & Kuma ['CBR'] , Tike ['STP'])
Rb4 = ctrl.Rule (Tipe ['STB'] & Tiha ['SML'] & Kuma ['BR'] , Tike ['STP'])
Rb5 = ctrl.Rule (Tipe ['STB'] & Tiha ['ML'] & Kuma ['STBR'] , Tike ['STP'])
Rb6 = ctrl.Rule (Tipe ['STB'] & Tiha ['ML'] & Kuma ['TBR'] , Tike ['STP'])
Rb7 = ctrl.Rule (Tipe ['STB'] & Tiha ['ML'] & Kuma ['CBR'] , Tike ['STP'])
Rb8 = ctrl.Rule (Tipe ['STB'] & Tiha ['ML'] & Kuma ['BR'] , Tike ['STP'])
Rb9 = ctrl.Rule (Tipe ['STB'] & Tiha ['CM'] & Kuma ['STBR'] , Tike ['STP'])
Rb10 = ctrl.Rule (Tipe ['STB'] & Tiha ['CM'] & Kuma ['TBR'] , Tike ['STP'])
Rb11 = ctrl.Rule (Tipe ['STB'] & Tiha ['CM'] & Kuma ['CBR'] , Tike ['TP'])
Rb12 = ctrl.Rule (Tipe ['STB'] & Tiha ['CM'] & Kuma ['BR'] , Tike ['TP'])
Rb13 = ctrl.Rule (Tipe ['STB'] & Tiha ['MRH'] & Kuma ['STBR'] , Tike ['STP'])
Rb14 = ctrl.Rule (Tipe ['STB'] & Tiha ['MRH'] & Kuma ['TBR'] , Tike ['STP'])
Rb15 = ctrl.Rule (Tipe ['STB'] & Tiha ['MRH'] & Kuma ['CBR'] , Tike ['TP'])
Rb16 = ctrl.Rule (Tipe ['STB'] & Tiha ['MRH'] & Kuma ['BR'] , Tike ['CP'])

Rb17 = ctrl.Rule (Tipe ['TB'] & Tiha ['SML'] & Kuma ['STBR'] , Tike ['STP'])
Rb18 = ctrl.Rule (Tipe ['TB'] & Tiha ['SML'] & Kuma ['TBR'] , Tike ['STP'])
Rb19 = ctrl.Rule (Tipe ['TB'] & Tiha ['SML'] & Kuma ['CBR'] , Tike ['STP'])
Rb20 = ctrl.Rule (Tipe ['TB'] & Tiha ['SML'] & Kuma ['BR'] , Tike ['STP'])
Rb21 = ctrl.Rule (Tipe ['TB'] & Tiha ['ML'] & Kuma ['STBR'] , Tike ['STP'])
Rb22 = ctrl.Rule (Tipe ['TB'] & Tiha ['ML'] & Kuma ['TBR'] , Tike ['STP'])
Rb23 = ctrl.Rule (Tipe ['TB'] & Tiha ['ML'] & Kuma ['CBR'] , Tike ['TP'])
Rb24 = ctrl.Rule (Tipe ['TB'] & Tiha ['ML'] & Kuma ['BR'] , Tike ['TP'])
Rb25 = ctrl.Rule (Tipe ['TB'] & Tiha ['CM'] & Kuma ['STBR'] , Tike ['STP'])
Rb26 = ctrl.Rule (Tipe ['TB'] & Tiha ['CM'] & Kuma ['TBR'] , Tike ['STP'])
Rb27 = ctrl.Rule (Tipe ['TB'] & Tiha ['CM'] & Kuma ['CBR'] , Tike ['TP'])
Rb28 = ctrl.Rule (Tipe ['TB'] & Tiha ['CM'] & Kuma ['BR'] , Tike ['TP'])
Rb29 = ctrl.Rule (Tipe ['TB'] & Tiha ['MRH'] & Kuma ['STBR'] , Tike ['TP'])
Rb30 = ctrl.Rule (Tipe ['TB'] & Tiha ['MRH'] & Kuma ['TBR'] , Tike ['TP'])
Rb31 = ctrl.Rule (Tipe ['TB'] & Tiha ['MRH'] & Kuma ['CBR'] , Tike ['CP'])
Rb32 = ctrl.Rule (Tipe ['TB'] & Tiha ['MRH'] & Kuma ['BR'] , Tike ['CP'])

Rb33 = ctrl.Rule (Tipe ['CB'] & Tiha ['SML'] & Kuma ['STBR'] , Tike ['STP'])
Rb34 = ctrl.Rule (Tipe ['CB'] & Tiha ['SML'] & Kuma ['TBR'] , Tike ['STP'])
Rb35 = ctrl.Rule (Tipe ['CB'] & Tiha ['SML'] & Kuma ['CBR'] , Tike ['TP'])
Rb36 = ctrl.Rule (Tipe ['CB'] & Tiha ['SML'] & Kuma ['BR'] , Tike ['TP'])
Rb37 = ctrl.Rule (Tipe ['CB'] & Tiha ['ML'] & Kuma ['STBR'] , Tike ['STP'])
Rb38 = ctrl.Rule (Tipe ['CB'] & Tiha ['ML'] & Kuma ['TBR'] , Tike ['STP'])
Rb39 = ctrl.Rule (Tipe ['CB'] & Tiha ['ML'] & Kuma ['CBR'] , Tike ['TP'])
Rb40 = ctrl.Rule (Tipe ['CB'] & Tiha ['ML'] & Kuma ['BR'] , Tike ['CP'])
Rb41 = ctrl.Rule (Tipe ['CB'] & Tiha ['CM'] & Kuma ['STBR'] , Tike ['STP'])
Rb42 = ctrl.Rule (Tipe ['CB'] & Tiha ['CM'] & Kuma ['TBR'] , Tike ['STP'])
Rb43 = ctrl.Rule (Tipe ['CB'] & Tiha ['CM'] & Kuma ['CBR'] , Tike ['CP'])
Rb44 = ctrl.Rule (Tipe ['CB'] & Tiha ['CM'] & Kuma ['BR'] , Tike ['CP'])
Rb45 = ctrl.Rule (Tipe ['CB'] & Tiha ['MRH'] & Kuma ['STBR'] , Tike ['TP'])
Rb46 = ctrl.Rule (Tipe ['CB'] & Tiha ['MRH'] & Kuma ['TBR'] , Tike ['TP'])
Rb47 = ctrl.Rule (Tipe ['CB'] & Tiha ['MRH'] & Kuma ['CBR'] , Tike ['CP'])
Rb48 = ctrl.Rule (Tipe ['CB'] & Tiha ['MRH'] & Kuma ['BR'] , Tike ['P'])

Rb49 = ctrl.Rule (Tipe ['B'] & Tiha ['SML'] & Kuma ['STBR'] , Tike ['STP'])
Rb50 = ctrl.Rule (Tipe ['B'] & Tiha ['SML'] & Kuma ['TBR'] , Tike ['STP'])
Rb51 = ctrl.Rule (Tipe ['B'] & Tiha ['SML'] & Kuma ['CBR'] , Tike ['TP'])
Rb52 = ctrl.Rule (Tipe ['B'] & Tiha ['SML'] & Kuma ['BR'] , Tike ['CP'])
Rb53 = ctrl.Rule (Tipe ['B'] & Tiha ['ML'] & Kuma ['STBR'] , Tike ['STP'])
Rb54 = ctrl.Rule (Tipe ['B'] & Tiha ['ML'] & Kuma ['TBR'] , Tike ['STP'])
Rb55 = ctrl.Rule (Tipe ['B'] & Tiha ['ML'] & Kuma ['CBR'] , Tike ['TP'])
Rb56 = ctrl.Rule (Tipe ['B'] & Tiha ['ML'] & Kuma ['BR'] , Tike ['CP'])
Rb57 = ctrl.Rule (Tipe ['B'] & Tiha ['CM'] & Kuma ['STBR'] , Tike ['STP'])
Rb58 = ctrl.Rule (Tipe ['B'] & Tiha ['CM'] & Kuma ['TBR'] , Tike ['STP'])
Rb59 = ctrl.Rule (Tipe ['B'] & Tiha ['CM'] & Kuma ['CBR'] , Tike ['CP'])
Rb60 = ctrl.Rule (Tipe ['B'] & Tiha ['CM'] & Kuma ['BR'] , Tike ['CP'])
Rb61 = ctrl.Rule (Tipe ['B'] & Tiha ['MRH'] & Kuma ['STBR'] , Tike ['STP'])
Rb62 = ctrl.Rule (Tipe ['B'] & Tiha ['MRH'] & Kuma ['TBR'] , Tike ['TP'])
Rb63 = ctrl.Rule (Tipe ['B'] & Tiha ['MRH'] & Kuma ['CBR'] , Tike ['P'])
Rb64 = ctrl.Rule (Tipe ['B'] & Tiha ['MRH'] & Kuma ['BR'] , Tike ['P'])

# %%
Tpk1 = ctrl.ControlSystem ([Rb1,Rb2,Rb3,Rb4,Rb5,Rb6,Rb7,Rb8,Rb9,Rb10,Rb11,Rb1,Rb12,Rb13,Rb14,Rb15,Rb16,Rb17,Rb18,Rb19,Rb20,Rb21,Rb22,Rb23,Rb23,Rb24,Rb25,Rb26,Rb27,Rb28,Rb29,Rb30,Rb31,Rb32,Rb33,Rb34,Rb5,Rb36,Rb37,Rb38,Rb39,Rb40,Rb41,Rb42,Rb43,Rb44,Rb45,Rb46,Rb47,Rb48,Rb49,Rb50,Rb51,Rb52,Rb53,Rb54,Rb55,Rb56,Rb56,Rb58,Rb59,Rb60,Rb61,Rb62,Rb63,Rb64])

# %%
Tpk = ctrl.ControlSystemSimulation (Tpk1) # untuk mensimulasikan rule base dalam bentuk grafik

# %%
Tpk.input['Tingkat Pelayanan'] = 8
Tpk.input['Tingkat Harga'] = 5
Tpk.input['Kualitas Makanan'] = 9

# %% [markdown]
# $ X =
# \begin{array}{||}
# ΣXi x Ai \over ΣAi
# \end{array}$

# %% [markdown]
# $ Centroid
# \begin{array}{||}
# {(1+2+3+4)x0+(5x0.5)+(6x0.5)+(7x0.5)+(8x0.5)+(9+10)x0 \over 0.5+0.5+0.5+0.5}
# \end{array}$
#
#
# <br/><br/>$ Centroid =
# \begin{array}{||}
# {(0+2.5+3+3.5+4) \over 2} = {13 \over 2} = 6.5
# \end{array}$

# %%
Tpk.compute() # Menghitung defuzzyfikasi
print (Tpk.output['Tingkat Kepuasan']) # Print variabel Tingkat kepuasan
Tike.view(sim=Tpk) # mensimulasikan bentuk grafik
# Out:
# 6.5
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
