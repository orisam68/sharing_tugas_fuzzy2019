# %% [markdown]
# # Nama  : TATA SATRIA TIMOR PERDANA
# # Nim   : 09011381722118
# # Kelas : SK5 BUKIT

# %% [markdown]
# # Intelligent Earthquake Prediction System Based On Neural Network
# # (Sistem Prediksi Gempa Bumi Berdasarkan Neural Network)

# %% [markdown]
# Memprediksi gempa bumi merupakan masalah penting dalam studi geografi. Prediksi yang akurat dari gempa bumi dapat membantu orang-orang dalam mengambil langkah-langkah untuk meminimalisir kerusakan seperti penghancuran bangunan, rusaknya lalu lintas yang terjadi dalam beberapa detik. Pusat Informasi Gempa (NEIC) menentukan lokasi dan semua gempa bumi yang terjadi diseluruh dunia dan segera menyebarkan informasi tersebut ke lembaga nasional dan internasional. Pada paper ini, untuk mendeteksi gempa bumi menggunakan jaringan syaraf tiruan. keuntungan dari metode ini bahwa tidak memerlukan asumsi, karena pada metode ini membuat prediksi yang sesuai dengan evolusi secara real time. Dalam memprediksi gempa bumi dilakukan dengan dua cara yaitu Automatic dilakukan secara otomatis dan Reviewed yang dilakukan secara manual.

# %% [markdown]
# ## 1. Dataset

# %% [markdown]
# Dataset yang digunakan mencakup catatan tanggal, waktu, latitude, longitude, magnitude, tipe, ID, sumber, lokasi, dan status. Output yang dihasilkan berupa binary klasifikasi atau dua kelas yaitu, Automatic dan Reviewed.

# %% [markdown]
# ## 2. Penyelesaian Dengan Python

# %% [markdown]
# ### - Import Library yang digunakan
#
# Preprocessing
#
# Ada sejumlah alat dan metode yang berbeda yang dapat digunakan untuk preprocessing, contohnya yaitu : transformasi yang memanipulasi data mentah untuk menghasilkan satu input, denoising yang menghilangkan noise dari data, dan lain sebagainya. MinMaxScaler itu memanipulasi sedemikian rupa sehingga menjadi data yang bernilai dari ranges 0 sampai 1.
#
# Categorical
#
# Berfungsi untuk mengkonversikan data binary menjadi data yang dikelompokkan, sehingga data tersebut dapat diambil bagian-bagiannya sebagai sebuah confusion matrix. Parameter yang digunakan dalam confusion matrix adalah Categorical dan prediksi hasil training.
#
# Model dan Layer
#
# Pada kasus ini, model yang digunakan untuk membuat hidden layer untuk memproses data adalah fungsi squential.Sedangkan layer sendiri menggunakantipe Danse yang melakukan training dengan menghubungkan setiap Neural Network secara sequential.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.activations import sigmoid
from keras.activations import relu
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from sklearn.metrics import confusion_matrix
from keras.optimizers import SGD

# %% [markdown]
# ### - load dataset yang digunakan
# "database.csv" karena nama file pada dataset yaitu database.csv

# %%
datasetasli = pd.read_csv("database.csv")

# %% [markdown]
# ### - Menampilkan Dataset Asli

# %%
datasetasli
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# 5      01/10/1965  13:36:32  -13.4050   166.6290  Earthquake   35.00
# 6      01/12/1965  13:32:25   27.3570    87.8670  Earthquake   20.00
# 7      01/15/1965  23:17:42  -13.3090   166.2120  Earthquake   35.00
# 8      01/16/1965  11:32:37  -56.4520   -27.0430  Earthquake   95.00
# 9      01/17/1965  10:43:17  -24.5630   178.4870  Earthquake  565.00
# 10     01/17/1965  20:57:41   -6.8070   108.9880  Earthquake  227.90
# 11     01/24/1965  00:11:17   -2.6080   125.9520  Earthquake   20.00
# 12     01/29/1965  09:35:30   54.6360   161.7030  Earthquake   55.00
# 13     02/01/1965  05:27:06  -18.6970  -177.8640  Earthquake  482.90
# 14     02/02/1965  15:56:51   37.5230    73.2510  Earthquake   15.00
# 15     02/04/1965  03:25:00  -51.8400   139.7410  Earthquake   10.00
# 16     02/04/1965  05:01:22   51.2510   178.7150  Earthquake   30.30
# 17     02/04/1965  06:04:59   51.6390   175.0550  Earthquake   30.00
# 18     02/04/1965  06:37:06   52.5280   172.0070  Earthquake   25.00
# 19     02/04/1965  06:39:32   51.6260   175.7460  Earthquake   25.00
# 20     02/04/1965  07:11:23   51.0370   177.8480  Earthquake   25.00
# 21     02/04/1965  07:14:59   51.7300   173.9750  Earthquake   20.00
# 22     02/04/1965  07:23:12   51.7750   173.0580  Earthquake   10.00
# 23     02/04/1965  07:43:43   52.6110   172.5880  Earthquake   24.00
# 24     02/04/1965  08:06:17   51.8310   174.3680  Earthquake   31.80
# 25     02/04/1965  08:33:41   51.9480   173.9690  Earthquake   20.00
# 26     02/04/1965  08:40:44   51.4430   179.6050  Earthquake   30.00
# 27     02/04/1965  12:06:08   52.7730   171.9740  Earthquake   30.00
# 28     02/04/1965  12:50:59   51.7720   174.6960  Earthquake   20.00
# 29     02/04/1965  14:18:29   52.9750   171.0910  Earthquake   25.00
# ...           ...       ...       ...        ...         ...     ...
# 23382  12/11/2016  17:26:10  -10.9640   161.5723  Earthquake   10.00
# 23383  12/14/2016  02:01:23   21.2897   144.4037  Earthquake   22.37
# 23384  12/14/2016  21:14:56   21.3697   144.2175  Earthquake   10.00
# 23385  12/16/2016  11:34:58   14.0882   -90.8691  Earthquake   71.26
# 23386  12/17/2016  10:51:10   -4.5049   153.5216  Earthquake   94.54
# 23387  12/17/2016  11:22:40   -4.4244   153.5419  Earthquake   83.36
# 23388  12/17/2016  11:27:39   -5.6497   153.9975  Earthquake   26.50
# 23389  12/18/2016  05:46:25  -10.2137   161.2177  Earthquake   37.39
# 23390  12/18/2016  06:15:46  -34.9886  -107.8694  Earthquake   10.00
# 23391  12/18/2016  06:39:42   -6.3046   154.3530  Earthquake   10.00
# 23392  12/18/2016  09:47:05    8.3489   137.6672  Earthquake   12.43
# 23393  12/18/2016  11:35:48  -10.1904   161.2187  Earthquake   57.52
# 23394  12/18/2016  13:30:11   -9.9640   -70.9714  Earthquake  622.54
# 23395  12/20/2016  04:21:29  -10.1773   161.2236  Earthquake   16.65
# 23396  12/20/2016  10:04:39   37.1442    84.9583  Earthquake   10.00
# 23397  12/20/2016  12:33:14  -10.1785   160.9149  Earthquake   10.00
# 23398  12/20/2016  20:07:53  -10.1549   160.7816  Earthquake   10.38
# 23399  12/21/2016  00:17:15   -7.5082   127.9206  Earthquake  152.00
# 23400  12/21/2016  16:43:57   21.5036   145.4172  Earthquake   12.05
# 23401  12/24/2016  01:32:16   -5.2453   153.5754  Earthquake   35.00
# 23402  12/24/2016  03:58:55   -5.1460   153.5166  Earthquake   30.00
# 23403  12/25/2016  14:22:27  -43.4029   -73.9395  Earthquake   38.00
# 23404  12/25/2016  14:32:13  -43.4810   -74.4771  Earthquake   14.93
# 23405  12/27/2016  23:20:56   45.7192    26.5230  Earthquake   97.00
# 23406  12/28/2016  08:18:01   38.3754  -118.8977  Earthquake   10.80
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  \
# 0              NaN                     NaN        6.0             MW
# 1              NaN                     NaN        5.8             MW
# 2              NaN                     NaN        6.2             MW
# 3              NaN                     NaN        5.8             MW
# 4              NaN                     NaN        5.8             MW
# 5              NaN                     NaN        6.7             MW
# 6              NaN                     NaN        5.9             MW
# 7              NaN                     NaN        6.0             MW
# 8              NaN                     NaN        6.0             MW
# 9              NaN                     NaN        5.8             MW
# 10             NaN                     NaN        5.9             MW
# 11             NaN                     NaN        8.2             MW
# 12             NaN                     NaN        5.5             MW
# 13             NaN                     NaN        5.6             MW
# 14             NaN                     NaN        6.0             MW
# 15             NaN                     NaN        6.1             MW
# 16             NaN                     NaN        8.7             MW
# 17             NaN                     NaN        6.0             MW
# 18             NaN                     NaN        5.7             MW
# 19             NaN                     NaN        5.8             MW
# 20             NaN                     NaN        5.9             MW
# 21             NaN                     NaN        5.9             MW
# 22             NaN                     NaN        5.7             MW
# 23             NaN                     NaN        5.7             MW
# 24             NaN                     NaN        5.7             MW
# 25             NaN                     NaN        5.6             MW
# 26             NaN                     NaN        7.3             MW
# 27             NaN                     NaN        6.5             MW
# 28             NaN                     NaN        5.6             MW
# 29             NaN                     NaN        6.4             MW
# ...            ...                     ...        ...            ...
# 23382          1.8                     NaN        5.5            MWW
# 23383          1.8                     NaN        6.0            MWW
# 23384          1.7                     NaN        5.5            MWW
# 23385          3.7                     NaN        5.5            MWW
# 23386          3.8                     NaN        7.9            MWW
# 23387          5.1                     NaN        5.6             MB
# 23388          3.6                     NaN        6.3            MWW
# 23389          3.4                     NaN        5.9            MWW
# 23390          1.6                     NaN        5.5            MWB
# 23391          1.6                     NaN        5.9            MWW
# 23392          2.9                     NaN        6.2            MWW
# 23393          5.2                     NaN        5.5             MB
# 23394          3.1                     NaN        6.4            MWW
# 23395          2.8                     NaN        6.4            MWW
# 23396          1.7                     NaN        5.6            MWW
# 23397          1.6                     NaN        6.0            MWW
# 23398          3.2                     NaN        5.5            MWB
# 23399          1.8                     NaN        6.7            MWW
# 23400          2.9                     NaN        5.9            MWW
# 23401          1.9                     NaN        6.0            MWW
# 23402          1.8                     NaN        5.8            MWW
# 23403          1.9                     NaN        7.6            MWW
# 23404          3.3                     NaN        5.6             MB
# 23405          1.8                     NaN        5.6            MWW
# 23406          1.3                    34.0        5.6             ML
# 23407          1.2                    40.0        5.6             ML
# 23408          2.0                    33.0        5.5             ML
# 23409          1.8                     NaN        5.9            MWW
# 23410          1.8                     NaN        6.3            MWW
# 23411          2.2                     NaN        5.5             MB
#
#          ...      Magnitude Seismic Stations  Azimuthal Gap  \
# 0        ...                             NaN            NaN
# 1        ...                             NaN            NaN
# 2        ...                             NaN            NaN
# 3        ...                             NaN            NaN
# 4        ...                             NaN            NaN
# 5        ...                             NaN            NaN
# 6        ...                             NaN            NaN
# 7        ...                             NaN            NaN
# 8        ...                             NaN            NaN
# 9        ...                             NaN            NaN
# 10       ...                             NaN            NaN
# 11       ...                             NaN            NaN
# 12       ...                             NaN            NaN
# 13       ...                             NaN            NaN
# 14       ...                             NaN            NaN
# 15       ...                             NaN            NaN
# 16       ...                             NaN            NaN
# 17       ...                             NaN            NaN
# 18       ...                             NaN            NaN
# 19       ...                             NaN            NaN
# 20       ...                             NaN            NaN
# 21       ...                             NaN            NaN
# 22       ...                             NaN            NaN
# 23       ...                             NaN            NaN
# 24       ...                             NaN            NaN
# 25       ...                             NaN            NaN
# 26       ...                             NaN            NaN
# 27       ...                             NaN            NaN
# 28       ...                             NaN            NaN
# 29       ...                             NaN            NaN
# ...      ...                             ...            ...
# 23382    ...                             NaN          45.00
# 23383    ...                             NaN          18.00
# 23384    ...                             NaN          18.00
# 23385    ...                             NaN          63.00
# 23386    ...                             NaN          13.00
# 23387    ...                            81.0          54.00
# 23388    ...                             NaN          31.00
# 23389    ...                             NaN          13.00
# 23390    ...                             8.0          65.00
# 23391    ...                             NaN          25.00
# 23392    ...                             NaN          16.00
# 23393    ...                           147.0          92.00
# 23394    ...                             NaN          11.00
# 23395    ...                             NaN          21.00
# 23396    ...                             NaN          15.00
# 23397    ...                             NaN          14.00
# 23398    ...                            41.0          19.00
# 23399    ...                             NaN          17.00
# 23400    ...                             NaN          21.00
# 23401    ...                             NaN          13.00
# 23402    ...                             NaN          14.00
# 23403    ...                             NaN          29.00
# 23404    ...                            83.0          96.00
# 23405    ...                             NaN          14.00
# 23406    ...                            20.0          35.86
# 23407    ...                            18.0          42.47
# 23408    ...                            18.0          48.58
# 23409    ...                             NaN          91.00
# 23410    ...                             NaN          26.00
# 23411    ...                           428.0          97.00
#
#        Horizontal Distance  Horizontal Error  Root Mean Square  \
# 0                      NaN               NaN               NaN
# 1                      NaN               NaN               NaN
# 2                      NaN               NaN               NaN
# 3                      NaN               NaN               NaN
# 4                      NaN               NaN               NaN
# 5                      NaN               NaN               NaN
# 6                      NaN               NaN               NaN
# 7                      NaN               NaN               NaN
# 8                      NaN               NaN               NaN
# 9                      NaN               NaN               NaN
# 10                     NaN               NaN               NaN
# 11                     NaN               NaN               NaN
# 12                     NaN               NaN               NaN
# 13                     NaN               NaN               NaN
# 14                     NaN               NaN               NaN
# 15                     NaN               NaN               NaN
# 16                     NaN               NaN               NaN
# 17                     NaN               NaN               NaN
# 18                     NaN               NaN               NaN
# 19                     NaN               NaN               NaN
# 20                     NaN               NaN               NaN
# 21                     NaN               NaN               NaN
# 22                     NaN               NaN               NaN
# 23                     NaN               NaN               NaN
# 24                     NaN               NaN               NaN
# 25                     NaN               NaN               NaN
# 26                     NaN               NaN               NaN
# 27                     NaN               NaN               NaN
# 28                     NaN               NaN               NaN
# 29                     NaN               NaN               NaN
# ...                    ...               ...               ...
# 23382                2.203               8.3            0.9000
# 23383                6.124               7.3            1.0100
# 23384                5.994               8.2            0.7400
# 23385                1.367               6.7            1.2600
# 23386                1.389               7.3            0.9700
# 23387                1.393              10.2            0.7100
# 23388                2.331               8.3            0.8100
# 23389                1.469               7.6            0.7100
# 23390               27.654              11.9            0.8000
# 23391                3.026               7.0            0.8700
# 23392                8.779               8.0            1.0200
# 23393                1.458               8.8            0.7900
# 23394                2.804               9.1            0.6500
# 23395                1.456               8.1            0.8900
# 23396                7.182               7.6            0.8300
# 23397                1.204               5.7            0.8800
# 23398                1.087               7.0            0.7000
# 23399                3.380               5.3            1.2000
# 23400                6.239               7.6            0.7600
# 23401                1.753               6.9            0.9100
# 23402                1.648               7.0            0.8500
# 23403                0.351               6.8            0.8000
# 23404                0.697               7.1            0.5200
# 23405                0.465               5.1            0.7800
# 23406                0.132               NaN            0.1988
# 23407                0.120               NaN            0.1898
# 23408                0.129               NaN            0.2187
# 23409                0.992               4.8            1.5200
# 23410                3.553               6.0            1.4300
# 23411                0.681               4.5            0.9100
#
#                               ID     Source Location Source Magnitude Source  \
# 0                   ISCGEM860706     ISCGEM          ISCGEM           ISCGEM
# 1                   ISCGEM860737     ISCGEM          ISCGEM           ISCGEM
# 2                   ISCGEM860762     ISCGEM          ISCGEM           ISCGEM
# 3                   ISCGEM860856     ISCGEM          ISCGEM           ISCGEM
# 4                   ISCGEM860890     ISCGEM          ISCGEM           ISCGEM
# 5                   ISCGEM860922     ISCGEM          ISCGEM           ISCGEM
# 6                   ISCGEM861007     ISCGEM          ISCGEM           ISCGEM
# 7                   ISCGEM861111     ISCGEM          ISCGEM           ISCGEM
# 8                ISCGEMSUP861125  ISCGEMSUP          ISCGEM           ISCGEM
# 9                   ISCGEM861148     ISCGEM          ISCGEM           ISCGEM
# 10                  ISCGEM861155     ISCGEM          ISCGEM           ISCGEM
# 11                  ISCGEM861299     ISCGEM          ISCGEM           ISCGEM
# 12                  ISCGEM861461     ISCGEM          ISCGEM           ISCGEM
# 13                  ISCGEM859136     ISCGEM          ISCGEM           ISCGEM
# 14                  ISCGEM859164     ISCGEM          ISCGEM           ISCGEM
# 15                  ISCGEM859200     ISCGEM          ISCGEM           ISCGEM
# 16     OFFICIAL19650204050122_30   OFFICIAL          ISCGEM         OFFICIAL
# 17               ISCGEMSUP859215  ISCGEMSUP          ISCGEM           ISCGEM
# 18                  ISCGEM859221     ISCGEM          ISCGEM           ISCGEM
# 19                  ISCGEM859222     ISCGEM          ISCGEM           ISCGEM
# 20               ISCGEMSUP859230  ISCGEMSUP          ISCGEM           ISCGEM
# 21                  ISCGEM859231     ISCGEM          ISCGEM           ISCGEM
# 22                  ISCGEM859233     ISCGEM          ISCGEM           ISCGEM
# 23               ISCGEMSUP859241  ISCGEMSUP          ISCGEM           ISCGEM
# 24                  ISCGEM859252     ISCGEM          ISCGEM           ISCGEM
# 25                  ISCGEM859261     ISCGEM          ISCGEM           ISCGEM
# 26                  ISCGEM859264     ISCGEM          ISCGEM           ISCGEM
# 27                  ISCGEM859324     ISCGEM          ISCGEM           ISCGEM
# 28                  ISCGEM859333     ISCGEM          ISCGEM           ISCGEM
# 29                  ISCGEM859358     ISCGEM          ISCGEM           ISCGEM
# ...                          ...        ...             ...              ...
# 23382                 US20008002         US              US               US
# 23383                 US200080M3         US              US               US
# 23384                 US200080TD         US              US               US
# 23385                 US2000819R         US              US               US
# 23386                 US200081V8         US              US               US
# 23387                 US200081VZ         US              US               US
# 23388                 US200081W0         US              US               US
# 23389                 US2000825R         US              US               US
# 23390                 US2000826E         US              US               US
# 23391                 US2000826M         US              US               US
# 23392                 US2000828L         US              US               US
# 23393                 US20008293         US              US               US
# 23394                 US200082AN         US              US               US
# 23395                 US200082PP         US              US               US
# 23396                 US200082S5         US              US               US
# 23397                 US200082TK         US              US               US
# 23398                 US10007LIX         US              US               US
# 23399                 US10007LKW         US              US               US
# 23400                 US10007LQE         US              US               US
# 23401                 US10007MF5         US              US               US
# 23402                 US10007MFP         US              US               US
# 23403                 US10007MN3         US              US               US
# 23404                 US10007MNB         US              US               US
# 23405                 US10007N3R         US              US               US
# 23406                 NN00570709         NN              NN               NN
# 23407                 NN00570710         NN              NN               NN
# 23408                 NN00570744         NN              NN               NN
# 23409                 US10007NAF         US              US               US
# 23410                 US10007NL0         US              US               US
# 23411                 US10007NTD         US              US               US
#
#           Status
# 0      Automatic
# 1      Automatic
# 2      Automatic
# 3      Automatic
# 4      Automatic
# 5      Automatic
# 6      Automatic
# 7      Automatic
# 8      Automatic
# 9      Automatic
# 10     Automatic
# 11     Automatic
# 12     Automatic
# 13     Automatic
# 14     Automatic
# 15     Automatic
# 16     Automatic
# 17     Automatic
# 18     Automatic
# 19     Automatic
# 20     Automatic
# 21     Automatic
# 22     Automatic
# 23     Automatic
# 24     Automatic
# 25     Automatic
# 26     Automatic
# 27     Automatic
# 28     Automatic
# 29     Automatic
# ...          ...
# 23382   Reviewed
# 23383   Reviewed
# 23384   Reviewed
# 23385   Reviewed
# 23386   Reviewed
# 23387   Reviewed
# 23388   Reviewed
# 23389   Reviewed
# 23390   Reviewed
# 23391   Reviewed
# 23392   Reviewed
# 23393   Reviewed
# 23394   Reviewed
# 23395   Reviewed
# 23396   Reviewed
# 23397   Reviewed
# 23398   Reviewed
# 23399   Reviewed
# 23400   Reviewed
# 23401   Reviewed
# 23402   Reviewed
# 23403   Reviewed
# 23404   Reviewed
# 23405   Reviewed
# 23406   Reviewed
# 23407   Reviewed
# 23408   Reviewed
# 23409   Reviewed
# 23410   Reviewed
# 23411   Reviewed
#
# [23412 rows x 21 columns]

# %% [markdown]
# ### - Menggunakan fitur dari pandas factorize.
# Pandas factorize atau pd.factorize() digunakan untuk mendapatkan nilai representasi numerik dari suatau array dengan mengidentifikasi nilai-nilai yang berbeda.

# %%
datasetbaru = datasetasli.apply(lambda col: pd.factorize(col, sort=True)[0])

# %% [markdown]
# ### - Menampilkan Data yang telah diencode

# %%
datasetbaru
# Out:
#         Date   Time  Latitude  Longitude  Type  Depth  Depth Error  \
# 0         34  11784     14682      16287     0   1670           -1
# 1        101   9865     11587      13420     0   1180           -1
# 2        133  15447      4821       2000     0    450           -1
# 3        235  16087       344       7646     0    359           -1
# 4        267  11611     13396      13050     0    359           -1
# 5        300  11665      6915      19759     0    665           -1
# 6        367  11603     15547       9828     0    450           -1
# 7        464  19887      6940      19586     0    665           -1
# 8        500   9900       624       7345     0   1320           -1
# 9        535   9194      3637      21221     0   3059           -1
# 10       535  17934      8606      11131     0   2300           -1
# 11       787    167     10462      12855     0    450           -1
# 12       961   8191     20146      19153     0    925           -1
# 13      1048   4667      5335        816     0   2784           -1
# 14      1083  13647     17158       9442     0    359           -1
# 15      1151   2913      1180      14810     0    218           -1
# 16      1151   4286     19405      21246     0    603           -1
# 17      1151   5207     19597      20980     0    599           -1
# 18      1151   5674     19872      20774     0    529           -1
# 19      1151   5721     19593      21010     0    529           -1
# 20      1151   6178     19319      21146     0    529           -1
# 21      1151   6247     19627      20896     0    450           -1
# 22      1151   6357     19638      20830     0    218           -1
# 23      1151   6654     19890      20798     0    516           -1
# 24      1151   6967     19656      20938     0    627           -1
# 25      1151   7360     19688      20895     0    450           -1
# 26      1151   7458     19499      21396     0    599           -1
# 27      1151  10386     19922      20772     0    599           -1
# 28      1151  10987     19637      20955     0    450           -1
# 29      1151  12285     19969      20703     0    529           -1
# ...      ...    ...       ...        ...   ...    ...          ...
# 23382  11723  14857      7357      19142     0    218           64
# 23383  11822   1680     14849      16073     0    489           64
# 23384  11822  18167     14851      16044     0    218           61
# 23385  11881   9947     13904       4526     0   1102           89
# 23386  11920   9305      9797      17996     0   1315           91
# 23387  11920   9763      9835      17998     0   1211          104
# 23388  11920   9836      9242      18092     0    547           88
# 23389  11956   4932      7600      19065     0    691           86
# 23390  11956   5376      2134       3832     0    218           60
# 23391  11956   5725      8859      18182     0    218           60
# 23392  11956   8362     12820      14514     0    295           81
# 23393  11956   9960      7609      19066     0    954          105
# 23394  11956  11561      7676       6037     0   3372           83
# 23395  12027   3744      7615      19067     0    392           79
# 23396  12027   8618     17040       9771     0    218           61
# 23397  12027  10764      7614      19022     0    218           60
# 23398  12027  17240      7623      19012     0    236           84
# 23399  12062    249      8276      13534     0   1843           64
# 23400  12062  14269     14859      16251     0    286           81
# 23401  12162   1268      9468      18005     0    665           65
# 23402  12162   3419      9517      17994     0    599           64
# 23403  12196  12344      1516       5528     0    699           65
# 23404  12196  12477      1511       5491     0    357           85
# 23405  12264  19948     18763       8364     0   1340           64
# 23406  12298   7134     17355       3398     0    250           53
# 23407  12298   7200     17364       3400     0    292           50
# 23408  12298   7904     17357       3399     0    179           66
# 23409  12298  10831     16971      14956     0    218           64
# 23410  12333  19200      7920      11417     0   1171           64
# 23411  12366  17247     17122      15180     0    284           70
#
#        Depth Seismic Stations  Magnitude  Magnitude Type   ...    \
# 0                          -1         28               5   ...
# 1                          -1         19               5   ...
# 2                          -1         31               5   ...
# 3                          -1         19               5   ...
# 4                          -1         19               5   ...
# 5                          -1         42               5   ...
# 6                          -1         25               5   ...
# 7                          -1         28               5   ...
# 8                          -1         28               5   ...
# 9                          -1         19               5   ...
# 10                         -1         25               5   ...
# 11                         -1         57               5   ...
# 12                         -1          0               5   ...
# 13                         -1          7               5   ...
# 14                         -1         28               5   ...
# 15                         -1         30               5   ...
# 16                         -1         61               5   ...
# 17                         -1         28               5   ...
# 18                         -1         14               5   ...
# 19                         -1         19               5   ...
# 20                         -1         25               5   ...
# 21                         -1         25               5   ...
# 22                         -1         14               5   ...
# 23                         -1         14               5   ...
# 24                         -1         14               5   ...
# 25                         -1          7               5   ...
# 26                         -1         48               5   ...
# 27                         -1         39               5   ...
# 28                         -1          7               5   ...
# 29                         -1         35               5   ...
# ...                       ...        ...             ...   ...
# 23382                      -1          0               9   ...
# 23383                      -1         28               9   ...
# 23384                      -1          0               9   ...
# 23385                      -1          0               9   ...
# 23386                      -1         54               9   ...
# 23387                      -1          7               0   ...
# 23388                      -1         32               9   ...
# 23389                      -1         25               9   ...
# 23390                      -1          0               6   ...
# 23391                      -1         25               9   ...
# 23392                      -1         31               9   ...
# 23393                      -1          0               0   ...
# 23394                      -1         35               9   ...
# 23395                      -1         35               9   ...
# 23396                      -1          7               9   ...
# 23397                      -1         28               9   ...
# 23398                      -1          0               6   ...
# 23399                      -1         42               9   ...
# 23400                      -1         25               9   ...
# 23401                      -1         28               9   ...
# 23402                      -1         19               9   ...
# 23403                      -1         51               9   ...
# 23404                      -1          7               0   ...
# 23405                      -1          7               9   ...
# 23406                      30          7               3   ...
# 23407                      36          7               3   ...
# 23408                      29          0               3   ...
# 23409                      -1         25               9   ...
# 23410                      -1         32               9   ...
# 23411                      -1          0               0   ...
#
#        Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                              -1             -1                   -1
# 1                              -1             -1                   -1
# 2                              -1             -1                   -1
# 3                              -1             -1                   -1
# 4                              -1             -1                   -1
# 5                              -1             -1                   -1
# 6                              -1             -1                   -1
# 7                              -1             -1                   -1
# 8                              -1             -1                   -1
# 9                              -1             -1                   -1
# 10                             -1             -1                   -1
# 11                             -1             -1                   -1
# 12                             -1             -1                   -1
# 13                             -1             -1                   -1
# 14                             -1             -1                   -1
# 15                             -1             -1                   -1
# 16                             -1             -1                   -1
# 17                             -1             -1                   -1
# 18                             -1             -1                   -1
# 19                             -1             -1                   -1
# 20                             -1             -1                   -1
# 21                             -1             -1                   -1
# 22                             -1             -1                   -1
# 23                             -1             -1                   -1
# 24                             -1             -1                   -1
# 25                             -1             -1                   -1
# 26                             -1             -1                   -1
# 27                             -1             -1                   -1
# 28                             -1             -1                   -1
# 29                             -1             -1                   -1
# ...                           ...            ...                  ...
# 23382                          -1            364                  672
# 23383                          -1             91                 1176
# 23384                          -1             91                 1172
# 23385                          -1            543                  462
# 23386                          -1             41                  469
# 23387                          81            455                  471
# 23388                          -1            221                  691
# 23389                          -1             41                  500
# 23390                           8            563                 1420
# 23391                          -1            161                  832
# 23392                          -1             71                 1292
# 23393                         145            793                  497
# 23394                          -1             21                  790
# 23395                          -1            121                  495
# 23396                          -1             61                 1241
# 23397                          -1             51                  413
# 23398                          41            101                  375
# 23399                          -1             81                  893
# 23400                          -1            121                 1183
# 23401                          -1             41                  576
# 23402                          -1             51                  546
# 23403                          -1            201                  120
# 23404                          83            820                  237
# 23405                          -1             51                  150
# 23406                          20            270                   53
# 23407                          18            338                   49
# 23408                          18            400                   52
# 23409                          -1            787                  342
# 23410                          -1            171                  915
# 23411                         238            827                  228
#
#        Horizontal Error  Root Mean Square    ID  Source  Location Source  \
# 0                    -1                -1  2579       4               20
# 1                    -1                -1  2580       4               20
# 2                    -1                -1  2581       4               20
# 3                    -1                -1  2582       4               20
# 4                    -1                -1  2583       4               20
# 5                    -1                -1  2584       4               20
# 6                    -1                -1  2585       4               20
# 7                    -1                -1  2586       4               20
# 8                    -1                -1  2710       5               20
# 9                    -1                -1  2587       4               20
# 10                   -1                -1  2588       4               20
# 11                   -1                -1  2589       4               20
# 12                   -1                -1  2590       4               20
# 13                   -1                -1  2530       4               20
# 14                   -1                -1  2531       4               20
# 15                   -1                -1  2532       4               20
# 16                   -1                -1  2766       8               20
# 17                   -1                -1  2706       5               20
# 18                   -1                -1  2533       4               20
# 19                   -1                -1  2534       4               20
# 20                   -1                -1  2707       5               20
# 21                   -1                -1  2535       4               20
# 22                   -1                -1  2536       4               20
# 23                   -1                -1  2708       5               20
# 24                   -1                -1  2537       4               20
# 25                   -1                -1  2538       4               20
# 26                   -1                -1  2539       4               20
# 27                   -1                -1  2540       4               20
# 28                   -1                -1  2541       4               20
# 29                   -1                -1  2542       4               20
# ...                 ...               ...   ...     ...              ...
# 23382               134               108  3597      11               44
# 23383               123               119  3598      11               44
# 23384               133                92  3599      11               44
# 23385               117               144  3600      11               44
# 23386               123               115  3603      11               44
# 23387               154                89  3604      11               44
# 23388               134                99  3605      11               44
# 23389               126                89  3606      11               44
# 23390               168                98  3607      11               44
# 23391               120               105  3608      11               44
# 23392               130               120  3609      11               44
# 23393               140                97  3610      11               44
# 23394               143                83  3611      11               44
# 23395               132               107  3612      11               44
# 23396               126               101  3613      11               44
# 23397               107               106  3614      11               44
# 23398               120                88  3222      11               44
# 23399               103               138  3223      11               44
# 23400               126                94  3224      11               44
# 23401               119               109  3225      11               44
# 23402               120               103  3226      11               44
# 23403               118                98  3227      11               44
# 23404               121                70  3228      11               44
# 23405               101                96  3229      11               44
# 23406                -1                27  2763       7               26
# 23407                -1                23  2764       7               26
# 23408                -1                30  2765       7               26
# 23409                98               170  3230      11               44
# 23410               110               161  3231      11               44
# 23411                93               109  3232      11               44
#
#        Magnitude Source  Status
# 0                    11       0
# 1                    11       0
# 2                    11       0
# 3                    11       0
# 4                    11       0
# 5                    11       0
# 6                    11       0
# 7                    11       0
# 8                    11       0
# 9                    11       0
# 10                   11       0
# 11                   11       0
# 12                   11       0
# 13                   11       0
# 14                   11       0
# 15                   11       0
# 16                   15       0
# 17                   11       0
# 18                   11       0
# 19                   11       0
# 20                   11       0
# 21                   11       0
# 22                   11       0
# 23                   11       0
# 24                   11       0
# 25                   11       0
# 26                   11       0
# 27                   11       0
# 28                   11       0
# 29                   11       0
# ...                 ...     ...
# 23382                20       1
# 23383                20       1
# 23384                20       1
# 23385                20       1
# 23386                20       1
# 23387                20       1
# 23388                20       1
# 23389                20       1
# 23390                20       1
# 23391                20       1
# 23392                20       1
# 23393                20       1
# 23394                20       1
# 23395                20       1
# 23396                20       1
# 23397                20       1
# 23398                20       1
# 23399                20       1
# 23400                20       1
# 23401                20       1
# 23402                20       1
# 23403                20       1
# 23404                20       1
# 23405                20       1
# 23406                14       1
# 23407                14       1
# 23408                14       1
# 23409                20       1
# 23410                20       1
# 23411                20       1
#
# [23412 rows x 21 columns]

# %% [markdown]
# ### - Mengambil nilai pada input feature dan output label
# Untuk feature :,0:20 artinya kolom 0 sampai dengan 19 karena pada dataset terdiri dari 21 kolom. Dan untuk label :,20 artinya kolom ke 20 sebagai output.

# %%
feature = np.array(datasetbaru.ix[:,0:20])
label = np.array(datasetbaru.ix[:,20])
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### - Distribusi Nilai Label

# %%
automatic = np.where(label == 0)[0]
reviewed = np.where(label == 1)[0]

print('distribusi awal label automatic = {0}, label reviewed = {1}'.format(len(automatic),len(reviewed)))

objects = ('Label Automatic','Label Reviewed')

label_pos = np.arange(len(objects))
distribution = [len(automatic), len(reviewed)]
fig = plt.figure(figsize=(20, 8), dpi=100)
plt.bar(label_pos, distribution, color='pink', edgecolor='red')
plt.xticks(label_pos, objects)
plt.ylabel('distribusi data')
plt.title('Distribusi data Original')
plt.show()
# Out:
# distribusi awal label automatic = 2639, label reviewed = 20773

# %% [markdown]
# ### - Normalisasi atau preprocessing data.
# Normalisasi disini merupakan penskalaan nilai atribut dari data sehingga bisa jatuh pada range tertentu. Metode normalisasi yang digunakan yaitu Min Max, Metode Min-Max merupakan metode normalisasi dengan melakukan transformasi linier terhadap data asli.

# %%
scaler = MinMaxScaler() 
feature_scale = scaler.fit_transform(feature)
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ### - Pembagian atau split data

# %%
training_data, testing_data, training_label, testing_label = train_test_split(feature_scale, label, test_size=0.50, shuffle=True)

# %% [markdown]
# ### - Model ANN
# Model ANN yang digunakan dengan hidden layer 1 dan node pada hidden layer 100, input layer 1 dan node input layer 20.
# Fungsi aktivasi yang digunakan yaitu Relu. Fungsi aktivasi ReLu merupakan fungsi aktivasi yang paling sering digunakan untuk saat ini. ReLu digunakan untuk hidden layer dan mempunyai output 0 jika input kurang dari 0. Jika input lebih besar dari 0, output sama dengan input.

# %%
model = Sequential()
model.add(Dense(units= 100, input_dim = 20, activation=relu))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation=sigmoid))
model.compile(optimizer=SGD(lr=0.01), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### - Akurasi Training dan Testing, serta Prediksi Training dan Testing
#
#
# Untuk mendapatkan hasil akurasi dan loss dari dataset, langkah selanjutnya yang harus dilakukan adalah fit model. Dimana pada proses ini terjadi proses training dengan parameter:
#
# 1. X yang telah diprocessing
# 2. Y yang telah dikonversi menjadi categorical
# 3. Banyaknya Epochs atau proses training
# 4. Batch_size
#
# Disini Epochs atau training yang saya lakukan sebanyak 50 kali.

# %%
acc_training = model.fit(training_data, training_label, validation_data=(testing_data, testing_label), epochs=50, batch_size=25)
acc_test = model.evaluate(testing_data, testing_label)
prediksi_label_training = model.predict(training_data)
prediksi_label_testing = model.predict(testing_data)
# Out:
# Train on 11706 samples, validate on 11706 samples
# Epoch 1/50
# 11706/11706 [==============================] - 2s 180us/step - loss: 0.2852 - accuracy: 0.8877 - val_loss: 0.2263 - val_accuracy: 0.8830
# Epoch 2/50
# 11706/11706 [==============================] - 2s 165us/step - loss: 0.1967 - accuracy: 0.8931 - val_loss: 0.1638 - val_accuracy: 0.88309 - ac
# Epoch 3/50
# 11706/11706 [==============================] - 2s 144us/step - loss: 0.1436 - accuracy: 0.9206 - val_loss: 0.1159 - val_accuracy: 0.9398
# Epoch 4/50
# 11706/11706 [==============================] - 2s 202us/step - loss: 0.1069 - accuracy: 0.9613 - val_loss: 0.0831 - val_accuracy: 0.9905
# Epoch 5/50
# 11706/11706 [==============================] - 2s 189us/step - loss: 0.0804 - accuracy: 0.9838 - val_loss: 0.0635 - val_accuracy: 0.9948
# Epoch 6/50
# 11706/11706 [==============================] - 2s 142us/step - loss: 0.0642 - accuracy: 0.9919 - val_loss: 0.0496 - val_accuracy: 0.9970
# Epoch 7/50
# 11706/11706 [==============================] - 2s 141us/step - loss: 0.0528 - accuracy: 0.9948 - val_loss: 0.0408 - val_accuracy: 0.9973
# Epoch 8/50
# 11706/11706 [==============================] - 2s 144us/step - loss: 0.0439 - accuracy: 0.9957 - val_loss: 0.0348 - val_accuracy: 0.9974
# Epoch 9/50
# 11706/11706 [==============================] - 2s 139us/step - loss: 0.0387 - accuracy: 0.9961 - val_loss: 0.0302 - val_accuracy: 0.9975
# Epoch 10/50
# 11706/11706 [==============================] - 2s 146us/step - loss: 0.0344 - accuracy: 0.9964 - val_loss: 0.0268 - val_accuracy: 0.9974
# Epoch 11/50
# 11706/11706 [==============================] - 2s 137us/step - loss: 0.0305 - accuracy: 0.9968 - val_loss: 0.0241 - val_accuracy: 0.9974
# Epoch 12/50
# 11706/11706 [==============================] - 2s 136us/step - loss: 0.0279 - accuracy: 0.9968 - val_loss: 0.0221 - val_accuracy: 0.9974
# Epoch 13/50
# 11706/11706 [==============================] - 2s 176us/step - loss: 0.0257 - accuracy: 0.9973 - val_loss: 0.0204 - val_accuracy: 0.9974
# Epoch 14/50
# 11706/11706 [==============================] - 2s 154us/step - loss: 0.0245 - accuracy: 0.9971 - val_loss: 0.0192 - val_accuracy: 0.9974
# Epoch 15/50
# 11706/11706 [==============================] - 2s 148us/step - loss: 0.0219 - accuracy: 0.9974 - val_loss: 0.0179 - val_accuracy: 0.9974
# Epoch 16/50
# 11706/11706 [==============================] - 2s 144us/step - loss: 0.0211 - accuracy: 0.9972 - val_loss: 0.0171 - val_accuracy: 0.9974
# Epoch 17/50
# 11706/11706 [==============================] - 2s 141us/step - loss: 0.0203 - accuracy: 0.9974 - val_loss: 0.0162 - val_accuracy: 0.9974
# Epoch 18/50
# 11706/11706 [==============================] - 2s 141us/step - loss: 0.0184 - accuracy: 0.9977 - val_loss: 0.0154 - val_accuracy: 0.9975
# Epoch 19/50
# 11706/11706 [==============================] - 2s 136us/step - loss: 0.0181 - accuracy: 0.9979 - val_loss: 0.0148 - val_accuracy: 0.9977
# Epoch 20/50
# 11706/11706 [==============================] - 2s 136us/step - loss: 0.0169 - accuracy: 0.9981 - val_loss: 0.0142 - val_accuracy: 0.9977
# Epoch 21/50
# 11706/11706 [==============================] - 2s 136us/step - loss: 0.0163 - accuracy: 0.9976 - val_loss: 0.0137 - val_accuracy: 0.9977
# Epoch 22/50
# 11706/11706 [==============================] - 2s 158us/step - loss: 0.0157 - accuracy: 0.9979 - val_loss: 0.0132 - val_accuracy: 0.9977
# Epoch 23/50
# 11706/11706 [==============================] - 2s 159us/step - loss: 0.0141 - accuracy: 0.9976 - val_loss: 0.0128 - val_accuracy: 0.9977
# Epoch 24/50
# 11706/11706 [==============================] - 2s 136us/step - loss: 0.0148 - accuracy: 0.9975 - val_loss: 0.0124 - val_accuracy: 0.9979
# Epoch 25/50
# 11706/11706 [==============================] - 2s 136us/step - loss: 0.0141 - accuracy: 0.9979 - val_loss: 0.0120 - val_accuracy: 0.9979
# Epoch 26/50
# 11706/11706 [==============================] - 2s 137us/step - loss: 0.0133 - accuracy: 0.9980 - val_loss: 0.0117 - val_accuracy: 0.9979
# Epoch 27/50
# 11706/11706 [==============================] - 2s 136us/step - loss: 0.0138 - accuracy: 0.9978 - val_loss: 0.0114 - val_accuracy: 0.9979
# Epoch 28/50
# 11706/11706 [==============================] - 2s 136us/step - loss: 0.0123 - accuracy: 0.9983 - val_loss: 0.0112 - val_accuracy: 0.9979
# Epoch 29/50
# 11706/11706 [==============================] - 2s 137us/step - loss: 0.0125 - accuracy: 0.9981 - val_loss: 0.0109 - val_accuracy: 0.9979
# Epoch 30/50
# 11706/11706 [==============================] - 2s 136us/step - loss: 0.0119 - accuracy: 0.9980 - val_loss: 0.0106 - val_accuracy: 0.9979
# Epoch 31/50
# 11706/11706 [==============================] - 2s 138us/step - loss: 0.0118 - accuracy: 0.9979 - val_loss: 0.0104 - val_accuracy: 0.9979
# Epoch 32/50
# 11706/11706 [==============================] - 2s 166us/step - loss: 0.0116 - accuracy: 0.9977 - val_loss: 0.0102 - val_accuracy: 0.9979
# Epoch 33/50
# 11706/11706 [==============================] - 2s 150us/step - loss: 0.0113 - accuracy: 0.9980 - val_loss: 0.0100 - val_accuracy: 0.9979
# Epoch 34/50
# 11706/11706 [==============================] - 2s 136us/step - loss: 0.0107 - accuracy: 0.9985 - val_loss: 0.0098 - val_accuracy: 0.9979
# Epoch 35/50
# 11706/11706 [==============================] - 2s 137us/step - loss: 0.0107 - accuracy: 0.9979 - val_loss: 0.0097 - val_accuracy: 0.9979
# Epoch 36/50
# 11706/11706 [==============================] - 2s 132us/step - loss: 0.0094 - accuracy: 0.9985 - val_loss: 0.0095 - val_accuracy: 0.9979
# Epoch 37/50
# 11706/11706 [==============================] - 2s 131us/step - loss: 0.0100 - accuracy: 0.9983 - val_loss: 0.0093 - val_accuracy: 0.9979
# Epoch 38/50
# 11706/11706 [==============================] - 2s 131us/step - loss: 0.0103 - accuracy: 0.9981 - val_loss: 0.0092 - val_accuracy: 0.9979
# Epoch 39/50
# 11706/11706 [==============================] - 2s 130us/step - loss: 0.0101 - accuracy: 0.9982 - val_loss: 0.0091 - val_accuracy: 0.9979
# Epoch 40/50
# 11706/11706 [==============================] - 2s 130us/step - loss: 0.0104 - accuracy: 0.9979 - val_loss: 0.0089 - val_accuracy: 0.9979
# Epoch 41/50
# 11706/11706 [==============================] - 2s 130us/step - loss: 0.0094 - accuracy: 0.9983 - val_loss: 0.0088 - val_accuracy: 0.9979
# Epoch 42/50
# 11706/11706 [==============================] - 2s 177us/step - loss: 0.0096 - accuracy: 0.9985 - val_loss: 0.0087 - val_accuracy: 0.9980
# Epoch 43/50
# 11706/11706 [==============================] - 2s 154us/step - loss: 0.0092 - accuracy: 0.9985 - val_loss: 0.0085 - val_accuracy: 0.9980
# Epoch 44/50
# 11706/11706 [==============================] - 2s 140us/step - loss: 0.0086 - accuracy: 0.9983 - val_loss: 0.0084 - val_accuracy: 0.9980
# Epoch 45/50
# 11706/11706 [==============================] - 2s 133us/step - loss: 0.0087 - accuracy: 0.9987 - val_loss: 0.0083 - val_accuracy: 0.9980
# Epoch 46/50
# 11706/11706 [==============================] - 2s 136us/step - loss: 0.0083 - accuracy: 0.9986 - val_loss: 0.0082 - val_accuracy: 0.9980
# Epoch 47/50
# 11706/11706 [==============================] - 2s 138us/step - loss: 0.0080 - accuracy: 0.9988 - val_loss: 0.0081 - val_accuracy: 0.9980
# Epoch 48/50
# 11706/11706 [==============================] - 2s 146us/step - loss: 0.0081 - accuracy: 0.9985 - val_loss: 0.0080 - val_accuracy: 0.9980
# Epoch 49/50
# 11706/11706 [==============================] - 2s 146us/step - loss: 0.0080 - accuracy: 0.9985 - val_loss: 0.0079 - val_accuracy: 0.9980
# Epoch 50/50
# 11706/11706 [==============================] - 2s 152us/step - loss: 0.0081 - accuracy: 0.9985 - val_loss: 0.0078 - val_accuracy: 0.9981
# 11706/11706 [==============================] - 0s 42us/step

# %% [markdown]
# ### - Prediksi Nilai Training

# %%
prediksi_label_training = model.predict(training_data)
print(prediksi_label_training)
# Out:
# [[0.9999961 ]
#  [0.999966  ]
#  [0.02310482]
#  ...
#  [0.9999887 ]
#  [0.9999714 ]
#  [0.9999968 ]]

# %% [markdown]
# ### - Prediksi Nilai Testing

# %%
prediksi_label_testing = model.predict(testing_data)
print(prediksi_label_testing)
# Out:
# [[0.99995494]
#  [0.99996376]
#  [0.9977293 ]
#  ...
#  [0.9999975 ]
#  [0.9999901 ]
#  [0.99948967]]

# %% [markdown]
# ### - Confusion Matrix

# %% [markdown]
# Confusion matrix adalah salah satu metrics yang paling intuitif dan mudah yang dapat digunakan untuk menemukan kebenaran dan akurasi model. Confusion matrix ini juga merupakan suatu metode yang dapat digunakan untuk mengukur kinerja dari suatu metode klasifikasi.  istilah-istilah dalam confusion matrix:
# 1. TP (True Positive)
#  True positive adalah ketika kelas aktual pada data point adalah 1 (True) dan prediksi juga 1 (True). Atau merupakan data positif yang terdeteksi benar.
# 2. TN (True Negative)
# True negative adalah ketika kelas actual pada data point 0 (False) dan prediksi juga 0 (negatif). Atau merupakan jumlah data  negatif yang terdeteksi dengan benar.
# 3. FP (False Positive)
# False positive adalah ketika kelas aktual pada data point 0 (False) dan prediksi 1 (True). False adalah karena model telah diprediksi salah dan positif karena kelas diprediksi yang positif (1). Atau merupakan data negatif yang terdeteksi dengan benar.
# 4. FN (False Negative)
# False negative adalah ketika kelas pada data point 1 (True) dan prediksi 0 (False). False karena model telah diprediksi benar dan negatif karena kelas diprediksi yang negatif (0). Atau merupakan kebalikan dari true positif dimana data positif namun terdeteksi sebagai data negatif.

# %%
import numpy as np
for x in np.arange(len(prediksi_label_training)):
    if (prediksi_label_training[x] > 0.5):
        prediksi_label_training[x] = 1
    else:
        prediksi_label_training[x] = 0
        
for x in np.arange(len(prediksi_label_testing)):
    if (prediksi_label_testing[x] > 0.5):
        prediksi_label_testing[x] = 1
    else:
        prediksi_label_testing[x] = 0

# %%
CM1 = confusion_matrix(training_label, prediksi_label_training).ravel()
TP1, FP1, FN1, TN1 = CM1
print(CM1)
# Out:
# [ 1269     0    17 10420]

# %%
CM2 = confusion_matrix(testing_label, prediksi_label_testing).ravel()
TP2, FP2, FN2, TN2 = CM2
print(CM2)
# Out:
# [ 1370     0    22 10314]

# %% [markdown]
# ### - Akurasi, Presisi, Sensitivity, Specificity, F1 Score, dan Error
# #### 1. Akurasi
# Akurasi dalam masalah klasifikasi merupakan prediksi jumlah benar dari kesuluruhan data. Nilai dari akurasi dapat menjelaskan seberapa akurat sistem dapat mengklasifikasikan data secara benar. Dirumuskan dengan:
# (TP + TN) / (TP+FP+FN+TN)

# %% [markdown]
# #### 2. Presisi
# Presisi merupakan tingkat dari ketepatan antara pengguna yang meminta informasi dengan jawaban yang diberikan oleh sistem. Presisi dalam sistem pengukuran dapat diartikan sebagai tingkatan dimana pengukuran berulang pada kondisi yang tidak berubah akan menghasilkan yang sama. Dirumuskan dengan:
# TP / TP + FP

# %% [markdown]
# #### 3. Sensitivity
# digunakan untuk mengukur proporsi positif yang sebenarnya dan diidentifikasi dengan benar. Dirumuskan dengan:
# TP/ (TP+FN)

# %% [markdown]
# #### 4. Specificity
# digunakan untuk mengukur proporsi negative yang sebenarnya dan diidentifikasi dengan benar. Dirumuskan dengan:
# TN / TN + FP

# %% [markdown]
# ### - Akurasi, Presisi, Sensitivity, Specificity, F1 Score, dan Error dari Training

# %%
Akurasi_training = (TP1 + TN1) / (TP1+FP1+FN1+TN1)
print(Akurasi_training)
# Out:
# 0.9985477532889117

# %%
Presisi_training = TP1 / TP1 + FP1
print(Presisi_training)
# Out:
# 1.0

# %%
Sensitivity_training = TP1/ (TP1+FN1)
print(Sensitivity_training)
# Out:
# 0.9867807153965785

# %%
Specificity_training = TN1 / TN1 + FP1
print(Specificity_training)
# Out:
# 1.0

# %%
F1_score_training = 2*(Sensitivity_training*Presisi_training)/(Sensitivity_training+Presisi_training)
print(F1_score_training)
# Out:
# 0.9933463796477495

# %%
Error_training = (FP1 + FN1) / (FP1 + FN1 + TN1 + TP1)
print(Error_training)
# Out:
# 0.0014522467110883307

# %% [markdown]
# ### - Akurasi, Presisi, Sensitivity, Specificity, F1 Score, dan Error dari Testing

# %%
Akurasi_testing = (TP2 + TN2) / (TP2+FP2+FN2+TN2)
print(Akurasi_testing)
# Out:
# 0.9981206219032974

# %%
Presisi_testing = TP2 / TP2 + FP2
print(Presisi_testing)
# Out:
# 1.0

# %%
Sensitivity_testing = TP2/ (TP2+FN2)
print(Sensitivity_testing)
# Out:
# 0.9841954022988506

# %%
Specificity_testing = TN2 / TN2 + FP2
print(Specificity_testing)
# Out:
# 1.0

# %%
F1_score_testing = 2*(Sensitivity_testing*Presisi_testing)/(Sensitivity_testing+Presisi_testing)
print(F1_score_testing)
# Out:
# 0.9920347574221579

# %%
Error_testing = (FP2 + FN2) / (FP2 + FN2 + TN2 + TP2)
print(Error_testing)
# Out:
# 0.0018793780967025456

# %% [markdown]
# ### - Menampilkan model Akurasi

# %%
fig,(ax0) = plt.subplots(nrows=1, figsize=(12,6))
ax0.plot(acc_training.history['accuracy'],'red', label='Akurasi Training')
ax0.plot(acc_training.history['val_accuracy'], 'blue', label='Akurasi Validasi')
ax0.plot(label='Accuracy', loc='upper left')
ax0.set_title('Model Accuracy')
ax0.set_xlabel("Epoch")
ax0.set_ylabel("Accuracy")
ax0.legend()

# %% [markdown]
# ### - Menampilkan Model Loss

# %%
fig,(ax1) = plt.subplots(nrows=1, figsize=(12,6))
ax1.plot(acc_training.history['loss'],'red', label='Loss Training')
ax1.plot(acc_training.history['val_loss'], 'blue', label='Loss Validasi')
ax1.plot(label='Loss', loc='upper left')
ax1.set_title('Model Loss')
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Loss")
ax1.legend()

# %% [markdown]
# ### - Menampilkan Model Summary

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 100)               2100
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 2,201
# Trainable params: 2,201
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. kesimpulan

# %% [markdown]
# jadi disini saya mendapatkan akurasi testing sebesar 0.9981206219032974% sedangkan akurasi training sebesar 0.9985477532889117%
