# %% [markdown]
# <div class="alert alert-info">
# <h2> <center> "KMS. IRWAN GUNAWAN"
#      <center> " 09011181722077 "
#      <center> " Kecerdasan Buatan "
#      <center> Prof.Dr.Ir.Siti Nurmaini,M.T.

# %% [markdown]
# <h1> <center>Aplikasi Fuzzy Logic Pada Pengaturan Air Cooler Untuk Ruangan Menggunakan Metode Mamdani

# %% [markdown]
# Sebuah kamar  hotel yang memiliki ac/pendingin udara  harus melakukan penghematan karna pengunaan energi  listrik yang digunakan untuk setiap kamar yang digunakan sangat besar. Dimana suhu ruangan diukur dari 1 - 41 derajat, dan banyak orang dalam ruangan 1 - 61 orang.output yang di butuhkan iyalah Kipas Pendigin dan Exhaust fan/Kipas keluar, dan kecepatan yang di butuhkan untuk satu rungan, Kipas pendingin 1 - 101 dan exhaust fan/kipas Keluaran 1 - 101.

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
from skfuzzy import control as ctrl

# %% [markdown]
# # A.PEMBENTUKAN HIMPUNAN FUZZY
#
# ### <strong>1.Pada sistem Fuzzy logic ini terdapat 2 variabel input, yaitu : </strong>
#     1. Suhu Ruangan(dibagi 5 bagian) :
#         a.Dingin (1 - 10)
#         b.Sejuk  (1 - 20)
#         c.Normal (10 - 30)
#         d.Hangat (20 - 40)
#         e.Panas  (30 - 40)
#
#     2. Orang/Banyak orang(dibagi 3 bagian) :
#        a.Sedikit (1 - 35)
#        b.Sedang  (20 - 50)
#        c.Banyak  (30 - 60)
#
# ### <strong>2.Pada sistem Fuzzy logic ini terdapat 2 variabel Otput, yaitu : </strong>
#     1. Kecepatan Kipas Pendingin(dibagi 5 bagian) :
#        a.Sangat Lambat (1 - 5)
#        b.Lambat        (1 - 50)
#        c.Sedang        (40 - 60)
#        d.Tinggi        (50 - 90)
#        e.Sangat tinggi (70 - 100)
#
#     2. Kecepatan Exhaust Fan(dibagi 5 bagian) :
#        a.Sangat Pelan  (1 - 5)
#        b.Pelan         (1 - 50)
#        c.Sedang        (40 - 60)
#        d.Cepat         (50 - 90)
#        e.Sangat cepat  (70 - 100)

# %% [markdown]
# ## Fuzzyfikasi Suhu

# %%
#rentan himpunan fuzzy input untuk Suhu (1-41)
suhu        = ctrl.Antecedent(np.arange (1,41,1),  'suhu')
#performa
suhu_x      = np.arange(1, 41, 1)

# %% [markdown]
#  ### Variabel Input Suhu Ruangan, yaitu : </strong>
#
#      Suhu Ruangan(dibagi 5 bagian) :
#         a.Dingin (1 - 10)
#         b.Sejuk  (1 - 20)
#         c.Normal (10 - 30)
#         d.Hangat (20 - 40)
#         e.Panas  (30 - 40)
#
# ### Nilai Linguistik pada Variabel Suhu ada 5, yaitu :
#
# - Suhu Dingin
# $$ Suhu Dingin [x] =
# \begin{cases}
#     \frac{(10-x)}{(10-1)} & ; 1 <  x \leq\ 10 \\
#     0 & ; x \geq 10
# \end{cases}
# $$
#
# - Suhu Sejuk
# $$ Suhu Sejuk [x] =
# \begin{cases}
#     0 & ; x \leq 1\\
#     \frac{(x-1)}{(10-1)} & ;1 < x \leq\ 10 \\
#     \frac{(20-x)}{(20-10)} & ; 10 \leq  x < \ 20 \\
#     0 & ; x \geq 20
# \end{cases}
# $$
#
# - Suhu Normal
# $$ Suhu Normal [x] =
# \begin{cases}
#     0 & ; x \leq 10\\
#     \frac{(x-10)}{(20-10)} & ;10 < x \leq\ 20 \\
#     \frac{(30-x)}{(30-20)} & ; 20 \leq  x <\ 30 \\
#     0 & ; x \geq 30
# \end{cases}
# $$
#
# - Suhu Hangat
# $$ Suhu Hangat [x] =
# \begin{cases}
#     0 & ; x \leq 20\\
#     \frac{(x-20)}{(30-20)} & ;20 < x \leq\ 30 \\
#     \frac{(40-x)}{(40-30)} & ; 30 \leq  x < \ 40 \\
#     0 & ; x \geq 30
# \end{cases}
# $$
#
# - Suhu Panas
# $$ Suhu Panas [x] =
# \begin{cases}
#     \frac{(x-30)}{(40-30)} & ; 30 <  x \leq\ 40 \\
#     0 & ; x \geq 40
# \end{cases}
# $$

# %% [markdown]
# ## Membership Function
# - Membership function yang digunakan yaitu fungsi segitiga atau triangular (trimf).
#
# Membership function dari Suhu,yaitu :

# %%
suhu['dingin']             = fuzz.trimf(suhu.universe, [1, 1, 10])
suhu['sejuk']              = fuzz.trimf(suhu.universe, [1, 10, 20])
suhu['normal']             = fuzz.trimf(suhu.universe, [10, 20, 30])
suhu['hangat']             = fuzz.trimf(suhu.universe, [20, 30, 40])
suhu['panas']              = fuzz.trimf(suhu.universe, [30, 40, 40])

# %% [markdown]
# ### Ploting Membership Function Suhu

# %% [markdown]
# Plotting fungsi keanggotaan $\mu SuhuDingin(x)$

# %%
suhu_dingin = fuzz.trimf(suhu_x,[1,1,10])
fig, (ax0) = plt.subplots(nrows=1,figsize=(6,6))
ax0.plot(suhu_x,suhu_dingin,'blue')
ax0.set_title('Suhu Dingin')
# Out:
# Text(0.5, 1.0, 'Suhu Dingin')

# %% [markdown]
# Plotting fungsi keanggotaan $\mu SuhuSejuk(x)$

# %%
suhu_sejuk = fuzz.trimf(suhu_x,[1,10,20])
fig1, (ax1) = plt.subplots(nrows=1,figsize=(6,6))
ax1.plot(suhu_x,suhu_sejuk,'orange')
ax1.set_title('Suhu Sejuk')
# Out:
# Text(0.5, 1.0, 'Suhu Sejuk')

# %% [markdown]
# Plotting fungsi keanggotaan $\mu SuhuNormal(x)$

# %%
suhu_normal = fuzz.trimf(suhu_x,[10,20,30])
fig2, (ax2) = plt.subplots(nrows=1,figsize=(6,6))
ax2.plot(suhu_x,suhu_normal,'green')
ax2.set_title('Suhu Normal')
# Out:
# Text(0.5, 1.0, 'Suhu Normal')

# %% [markdown]
# Plotting fungsi keanggotaan $\mu SuhuHangat(x)$

# %%
suhu_hangat = fuzz.trimf(suhu_x,[20,30,40])
fig3, (ax3) = plt.subplots(nrows=1,figsize=(6,6))
ax3.plot(suhu_x,suhu_hangat,'red')
ax3.set_title('Suhu Hangat')
# Out:
# Text(0.5, 1.0, 'Suhu Hangat')

# %% [markdown]
# Plotting fungsi keanggotaan $\mu SuhuPanas(x)$

# %%
suhu_panas = fuzz.trimf(suhu_x,[30,40,40])
fig3, (ax3) = plt.subplots(nrows=1,figsize=(6,6))
ax3.plot(suhu_x,suhu_panas,'purple')
ax3.set_title('Suhu Panas')
# Out:
# Text(0.5, 1.0, 'Suhu Panas')

# %% [markdown]
# Plotting ke empat fungsi keanggotaan suhu

# %%
suhu.view()
# Out:
# C:\ProgramData\Anaconda4\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# Rumus mencari nilai Suhu.
#
# Karena nilai Suhu "15" berada diantara sejuk dan normal, maka :
#
#     Suhu "Sejuk"   a:1  b:10  c:20
#     = (c-x)/(c-b)
#     = (20-15)/(20-10)
#     = 5/10
#     = 0,5
#
#     Suhu "Normal"  a:10  b:20  c:30
#     = (x-a)/(b-a)
#     = (15-10)/(20-10)
#     = 5/10
#     = 0,5

# %% [markdown]
# ## Fuzzyfikasi Orang

# %%
#rentan himpunan fuzzy input untuk Orang (1-61)
orang       = ctrl.Antecedent(np.arange (1,61,1),  'orang')
orang_x = np.arange(1,61,1)

# %% [markdown]
# ### Variabel input Orang, yaitu : </strong>
#      Orang/Banyak orang (dibagi 3 bagian) :
#        a.Sedikit (1 - 35)
#        b.Sedang  (20 - 50)
#        c.Banyak  (30 - 60)
#
#
# ## Nilai Linguistik pada Variabel Orang ada 3, yaitu :
#
# - Orang Sedikit
# $$ Orang Sedikit [x] =
# \begin{cases}
#     \frac{(35-x)}{(35-20)} & ; x \leq\ 35 \\
# \end{cases}
# $$
#
# - Orang Sedang
# $$ Orang Sedang [x] =
# \begin{cases}
#     0 & ; x \leq 20\\
#     \frac{(x-20)}{(35-20)} & ;20 < x \leq\ 35 \\
#     \frac{(50-x)}{(50-35)} & ; 35 \leq  x < \ 50 \\
#     0 & ; x \geq 50
# \end{cases}
# $$
#
# - Orang Banyak
# $$ Orang banyak [x] =
# \begin{cases}
#     \frac{(x-30)}{(60-30)} & ; 30 <  x \leq\ 60 \\
# \end{cases}
# $$

# %% [markdown]
# ## Membership Function
# - Membership function yang digunakan yaitu fungsi segitiga atau triangular (trimf).
#
# Membership function dari Orang, yaitu :

# %%
orang['sedikit']           = fuzz.trapmf(orang.universe, [1, 1, 20, 35])
orang['sedang']            = fuzz.trimf(orang.universe, [20, 35, 50])
orang['banyak']            = fuzz.trapmf(orang.universe, [30, 50, 60, 60])

# %% [markdown]
# ### Ploting Membership Function Orang

# %% [markdown]
# Plotting fungsi keanggotaan $\mu OrangSedikit(x)$

# %%
orang_sedikit = fuzz.trapmf(orang_x,[1,1,20,35])
fig, (ax0) = plt.subplots(nrows=1,figsize=(6,6))
ax0.plot(orang_x,orang_sedikit,'blue')
ax0.set_title('Orang Sedikit')
# Out:
# Text(0.5, 1.0, 'Orang Sedikit')

# %% [markdown]
# Plotting fungsi keanggotaan $\mu OrangSedang(x)$

# %%
orang_sedang = fuzz.trimf(orang_x,[20,35,50])
fig1, (ax1) = plt.subplots(nrows=1,figsize=(6,6))
ax1.plot(orang_x,orang_sedang,'orange')
ax1.set_title('Orang Sedang')
# Out:
# Text(0.5, 1.0, 'Orang Sedang')

# %% [markdown]
# Plotting fungsi keanggotaan $\mu OrangBanyak(x)$

# %%
orang_banyak = fuzz.trapmf(orang_x,[30,50,60,60])
fig2, (ax2) = plt.subplots(nrows=1,figsize=(6,6))
ax2.plot(orang_x,orang_banyak,'green')
ax2.set_title('Orang Banyak')
# Out:
# Text(0.5, 1.0, 'Orang Banyak')

# %% [markdown]
# Plotting ke ketiga fungsi keanggotaan Orang

# %%
orang.view()

# %% [markdown]
# Rumus mencari nilai Orang.
#
# Karena nilai Orang "10" berada disedikit, maka :
#
#     Orang "Sedikit"  = 1

# %% [markdown]
# ## Fuzzyfikasi Kipas

# %%
#rentan himpunan fuzzy otput untuk Kipas (1-101)
kipas       = ctrl.Consequent(np.arange (1,101,1), 'kipas')
kipas_x = np.arange(1,100,1)

# %% [markdown]
# ### Variabel Otput Kipas, yaitu : </strong>
#     Kecepatan Kipas Pendingin(dibagi 5 bagian) :
#        a.Sangat Lambat (1 - 5)
#        b.Lambat        (1 - 50)
#        c.Sedang        (40 - 60)
#        d.Tinggi        (50 - 90)
#        e.Sangat tinggi (70 - 100)
#
# ### Nilai Linguistik pada Variabel Kipas ada 5, yaitu :
#
# - Kipas Sangat Lambat
# $$ Suhu Sangat lambat [x] =
# \begin{cases}
#     \frac{(5-x)}{(5-1)} & ; 1 <  x \leq\ 5 \\
#     0 & ; x \geq 5
# \end{cases}
# $$
#
# - Kipas Lambat
# $$ Kipas Lambat [x] =
# \begin{cases}
#     0 & ; x \leq 1\\
#     \frac{(x-1)}{(25-1)} & ;1 < x \leq\ 25 \\
#     \frac{(50-x)}{(50-25)} & ; 25 \leq  x <\ 50 \\
#     0 & ; x \geq 50
# \end{cases}
# $$
#
# - Kipas Sedang
# $$ Kipas Sedang [x] =
# \begin{cases}
#     0 & ; x \leq 40\\
#     \frac{(x-40)}{(50-40)} & ;40 < x \leg\ 50 \\
#     \frac{(60-x)}{(60-50)} & ; 50 \leq  x < \ 60 \\
#     0 & ; x \geq 60
# \end{cases}
# $$
#
# - Kipas Cepat
# $$ Kipas Cepat [x] =
# \begin{cases}
#     0 & ; x \leq 50\\
#     \frac{(x-50)}{(70-50)} & ;50 < x \leq\ 70 \\
#     \frac{(90-x)}{(90-70)} & ; 70 \leq  x < \ 90 \\
#     0 & ; x \geq 90
# \end{cases}
# $$
#
# - Kipas Sangat Cepat
# $$ Kipas Sangat Cepat [x] =
# \begin{cases}
#     \frac{(x-70)}{(100-70)} & ; 70 <  x \leq\ 100 \\
#     0 & ; x \geq 100
# \end{cases}
# $$

# %% [markdown]
# ## Membership Function
# - Membership function yang digunakan yaitu fungsi segitiga atau triangular (trimf).
#
# Membership function dari Kipas, yaitu :

# %%
kipas['sangat lambat']     = fuzz.trimf(kipas.universe, [1, 1, 5])
kipas['lambat']            = fuzz.trimf(kipas.universe, [1, 25, 50])
kipas['sedang']            = fuzz.trimf(kipas.universe, [40, 50, 60])
kipas['cepat']             = fuzz.trimf(kipas.universe, [50, 70, 90])
kipas['sangat cepat']      = fuzz.trimf(kipas.universe, [70, 100, 100])

# %% [markdown]
# ## Plotting fungsi keanggotaan Kipas

# %% [markdown]
# Plot fungsi keanggotaan $\mu KipasSagatLambat(x) $

# %%
kipas_sangat_lambat = fuzz.trimf(kipas_x,[1,1,5])
fig, (ax0) = plt.subplots(nrows=1,figsize=(6,6))
ax0.plot(kipas_x,kipas_sangat_lambat,'blue')
ax0.set_title('Kipas Sangat Lambat')
# Out:
# Text(0.5, 1.0, 'Kipas Sangat Lambat')

# %% [markdown]
# Plot fungsi keanggotaan $\mu KipasLambat(x) $

# %%
kipas_lambat = fuzz.trimf(kipas_x,[1,25,50])
fig1, (ax1) = plt.subplots(nrows=1,figsize=(6,6))
ax1.plot(kipas_x,kipas_lambat,'orange')
ax1.set_title('Kipas Lambat')
# Out:
# Text(0.5, 1.0, 'Kipas Lambat')

# %% [markdown]
# Plot fungsi keanggotaan $\mu KipasSedang(x) $

# %%
kipas_sedang = fuzz.trimf(kipas_x,[40,50,60])
fig2, (ax2) = plt.subplots(nrows=1,figsize=(6,6))
ax2.plot(kipas_x,kipas_sedang,'green')
ax2.set_title('Kipas Sedang')
# Out:
# Text(0.5, 1.0, 'Kipas Sedang')

# %% [markdown]
# Plot fungsi keanggotaan $\mu KipasCepat(x) $

# %%
kipas_cepat = fuzz.trimf(kipas_x,[50,70,90])
fig3, (ax3) = plt.subplots(nrows=1,figsize=(6,6))
ax3.plot(kipas_x,kipas_cepat,'red')
ax3.set_title('Kipas Cepat')
# Out:
# Text(0.5, 1.0, 'Kipas Cepat')

# %% [markdown]
# Plot fungsi keanggotaan $\mu KipasSangatCepat(x) $

# %%
kipas_sangat_cepat = fuzz.trimf(kipas_x,[70,100,100])
fig4, (ax4) = plt.subplots(nrows=1,figsize=(6,6))
ax4.plot(kipas_x,kipas_sangat_cepat,'purple')
ax4.set_title('Kipas Sangat Cepat')
# Out:
# Text(0.5, 1.0, 'Kipas Sangat Cepat')

# %% [markdown]
# Plotting ke lima fungsi keanggotaan kipas

# %%
kipas.view()

# %% [markdown]
# ## Fuzzyfikasi Exhaust

# %%
#rentan himpunan fuzzy otput untuk Exhaust (1-101)
exhaust     = ctrl.Consequent(np.arange (1,101,1), 'exhaust')
exhaust_x   = np.arange(1,101,1)

# %% [markdown]
#     2. Kecepatan Exhaust Fan(dibagi 5 bagian) :
#        a.Sangat Pelan  (1 - 5)
#        b.Pelan         (1 - 50)
#        c.Sedang        (40 - 60)
#        d.Cepat         (50 - 90)
#        e.Sangat cepat  (70 - 100)
#
#
# #### 3.4.Nilai Linguistik pada Variabel Exhaust ada 5, yaitu :
#
# - Exhaust Sangat Pelan
# $$ Exhaust Sangat Pelan [x] =
# \begin{cases}
#     \frac{(5-x)}{(5-1)} & ; 1 <  x \leq\ 5 \\
#     0 & ; x \geq 5
# \end{cases}
# $$
#
# - Exhaust Pelan
# $$ Exhaust Pelan [x] =
# \begin{cases}
#     0 & ; x \leq 1\\
#     \frac{(x-1)}{(25-1)} & ;1 < x \leq\ 25 \\
#     \frac{(50-x)}{(50-25)} & ; 25 \leq  x <\ 50 \\
#     0 & ; x \geq 50
# \end{cases}
# $$
#
# - Exhaust Sedang
# $$ Exhaust Sedang [x] =
# \begin{cases}
#     0 & ; x \leq 40\\
#     \frac{(x-40)}{(50-40)} & ;40 < x \leq\ 50 \\
#     \frac{(60-x)}{(60-50)} & ; 50 \leq  x < \ 60 \\
#     0 & ; x \geq 60
# \end{cases}
# $$
#
# - Exhaust Cepat
# $$ Exhaust Cepat [x] =
# \begin{cases}
#     0 & ; x \leq 50\\
#     \frac{(x-50)}{(70-50)} & ;50 < x \leq\ 70 \\
#     \frac{(90-x)}{(90-70)} & ; 70 \leq  x <\ 90 \\
#     0 & ; x \geq 90
# \end{cases}
# $$
#
# - Exhaust Sangat Cepat
# $$ Exhaust Sangat Cepat [x] =
# \begin{cases}
#     \frac{(x-70)}{(100-70)} & ; 70 <  x \leq\ 100 \\
#     0 & ; x \geq 100
# \end{cases}
# $$

# %% [markdown]
# ## Membership Function
# - Membership function yang digunakan yaitu fungsi segitiga atau triangular (trimf).
#
# Membership function dari Exhaust, yaitu :

# %%
exhaust['sangat pelan']    = fuzz.trimf(exhaust.universe, [1, 1, 5])
exhaust['pelan']           = fuzz.trimf(exhaust.universe, [1, 25, 50])
exhaust['sedang']          = fuzz.trimf(exhaust.universe, [40, 50, 60])
exhaust['cepat']           = fuzz.trimf(exhaust.universe, [50, 70, 90])
exhaust['sangat cepat']    = fuzz.trimf(exhaust.universe, [70, 100, 100])

# %% [markdown]
# ## Plotting fungsi keanggotaan Exhaust

# %% [markdown]
# Plot fungsi keanggotaan $\mu ExhaustSagatLambat(x) $

# %%
exhaust_sangat_pelan = fuzz.trimf(exhaust_x,[1,1,5])
fig, (ax0) = plt.subplots(nrows=1,figsize=(6,6))
ax0.plot(exhaust_x,exhaust_sangat_pelan,'blue')
ax0.set_title('Exhaust Sangat Pelan')
# Out:
# Text(0.5, 1.0, 'Exhaust Sangat Pelan')

# %% [markdown]
# Plot fungsi keanggotaan $\mu ExhaustLambat(x) $

# %%
exhaust_pelan = fuzz.trimf(exhaust_x,[1,25,50])
fig1, (ax1) = plt.subplots(nrows=1,figsize=(6,6))
ax1.plot(exhaust_x,exhaust_pelan,'orange')
ax1.set_title('Exhaust Pelan')
# Out:
# Text(0.5, 1.0, 'Exhaust Pelan')

# %% [markdown]
# Plot fungsi keanggotaan $\mu ExhaustSedang(x) $

# %%
exhaust_sedang = fuzz.trimf(exhaust_x,[40,50,60])
fig2, (ax2) = plt.subplots(nrows=1,figsize=(6,6))
ax2.plot(exhaust_x,exhaust_sedang,'green')
ax2.set_title('Exhaust Sedang')
# Out:
# Text(0.5, 1.0, 'Exhaust Sedang')

# %% [markdown]
# Plot fungsi keanggotaan $\mu ExhaustCepat(x) $

# %%
exhaust_cepat = fuzz.trimf(exhaust_x,[50,70,90])
fig3, (ax3) = plt.subplots(nrows=1,figsize=(6,6))
ax3.plot(exhaust_x,exhaust_cepat,'red')
ax3.set_title('Exhaust Cepat')
# Out:
# Text(0.5, 1.0, 'Exhaust Cepat')

# %% [markdown]
# Plot fungsi keanggotaan $\mu ExhaustSangatCepat(x) $

# %%
exhaust_sangat_cepat = fuzz.trimf(exhaust_x,[50,70,90])
fig4, (ax4) = plt.subplots(nrows=1,figsize=(6,6))
ax4.plot(exhaust_x,exhaust_sangat_cepat,'purple')
ax4.set_title('Exhaust Sangat Cepat')
# Out:
# Text(0.5, 1.0, 'Exhaust Sangat Cepat')

# %% [markdown]
# Plotting ke lima fungsi keanggotaan Exhaust

# %%
exhaust.view()

# %% [markdown]
# ## Inferencing
#     Pada tahap inferencing, membuat aturan-aturan fuzzy yang dinyatakan dalam bentuk IF .... THEN ....
#
#     Pada sistem ini berdasarkan jumlah fuzzifikasi dari variabel suhu yang berjumlah 5 dan fuzzifikasi dari variabel orang yang berjumlah 3, maka rule yang dibuat berjumlah 5 x 3 = 15 rule

# %% [markdown]
#     1. IF Suhu DINGIN dan Orang SEDIKIT THEN Kipas SANGAT LAMBAT dan Exhaust SANGAT PELAN
#     2. IF Suhu DINGIN dan Orang SEDANG THEN Kipas SEDANG dan Exhaust SEDANG
#     3. IF Suhu DINGIN dan Orang BANYAK THEN Kipas CEPAT dan Exhaust SEDANG
#
#     4. IF Suhu SEJUK dan Orang SEDIKIT THEN Kipas LAMBAT dan Exhaust PELAN
#     5. IF Suhu SEJUK dan Orang SEDANG THEN Kipas CEPAT dan Exhaust SEDANG
#     6. IF Suhu SEJUK dan Orang BANYAK THEN Kipas CEPAT dan Exhaust CEPAT
#
#     7. IF Suhu NORMAL dan Orang SEDIKIT THEN Kipas CEPAT  dan Exhaust SEDANG
#     8. IF Suhu NORMAL dan Orang SEDANG THEN Kipas SEDANG dan Exhaust CEPAT
#     9. IF Suhu NORMAL dan Orang BANYAK THEN Kipas CEPAT dan Exhaust CEPAT
#
#     10. IF Suhu HANGAT dan Orang SEDIKIT THEN Kipas CEPAT dan Exhaust SEDANG
#     11. IF Suhu HANGAT dan Orang SEDANG THEN Kipas SANGAT CEPAT dan Exhaust CEPAT
#     12. IF Suhu HANGAT dan Orang BANYAK THEN Kipas SANGAT CEPAT dan Exhaust SANGAT CEPAT
#
#     13. IF Suhu PANAS dan Orang SEDIKIT THEN Kipas CEPAT dan Exhaust SEDANG
#     14. IF Suhu PANAS dan Orang SEDANG THEN Kipas SANGAT CEPAT dan Exhaust CEPAT
#     15. IF Suhu PANAS dan Orang BANYAK THEN Kipas SANGAT CEPAT dan Exhaust SANGAT CEPAT

# %%
rule1 = ctrl.Rule(suhu['dingin'] & orang['sedikit'],([kipas["sangat lambat"],exhaust["sangat pelan"]]))
rule2 = ctrl.Rule(suhu['dingin'] & orang['sedang'],([kipas["sedang"],exhaust["sedang"]]))
rule3 = ctrl.Rule(suhu['dingin'] & orang['banyak'],([kipas["cepat"],exhaust["sedang"]]))

rule4 = ctrl.Rule(suhu['sejuk'] & orang['sedikit'],[kipas["lambat"],exhaust["pelan"]])
rule5 = ctrl.Rule(suhu['sejuk'] & orang['sedang'],[kipas["cepat"],exhaust["sedang"]])
rule6 = ctrl.Rule(suhu['sejuk'] & orang['banyak'],[kipas["cepat"],exhaust["cepat"]])

rule7 = ctrl.Rule(suhu['normal'] & orang['sedikit'],[kipas["cepat"],exhaust["sedang"]])
rule8 = ctrl.Rule(suhu['normal'] & orang['sedang'],[kipas["sedang"],exhaust["cepat"]])
rule9 = ctrl.Rule(suhu['normal'] & orang['banyak'],[kipas["cepat"],exhaust["cepat"]])

rule10 = ctrl.Rule(suhu['hangat'] & orang['sedikit'],[kipas["cepat"],exhaust["sedang"]])
rule11 = ctrl.Rule(suhu['hangat'] & orang['sedang'],[kipas["sangat cepat"],exhaust["cepat"]])
rule12 = ctrl.Rule(suhu['hangat'] & orang['banyak'],[kipas["sangat cepat"],exhaust["sangat cepat"]])

rule13 = ctrl.Rule(suhu['panas'] & orang['sedikit'],[kipas["cepat"],exhaust["sedang"]])
rule14 = ctrl.Rule(suhu['panas'] & orang['sedang'],[kipas["sangat cepat"],exhaust["cepat"]])
rule15 = ctrl.Rule(suhu['panas'] & orang['banyak'],[kipas["sangat cepat"],exhaust["sangat cepat"]])

rule1.view()
# Out:
# C:\ProgramData\Anaconda4\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\ProgramData\Anaconda4\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1dd68bbb518>)

# %% [markdown]
# Mencari Nilai Rule
#
#     Rule4 = IF Suhu "Sejuk" dan Orang "Sedikit" Then Kipas "Lambat" dan Exhaust "Pelan"
#           = MIN (0,5 , 1)
#           = 0.5
#
#     Rule7 = IF Suhu "Normal" dan Orang "Sedikit" Then Kipas "Cepat" dan Exhaust "Sedang"
#           = MIN (0,5 , 1)
#           = 0.5

# %% [markdown]
# ## Rule Evaluation

# %%
keluaran_ctrl = ctrl.ControlSystem([rule1, rule2, rule3,rule4, rule5, rule6,rule7, rule8, rule9, rule10, 
                                  rule11, rule12, rule13, rule14, rule15])

# %% [markdown]
# ## Defuzzyfikasi

# %%
tingkat = ctrl.ControlSystemSimulation(keluaran_ctrl)

# %% [markdown]
#     Input suhu kita masukan 15 dan orang 10.
#     Mencetak hasil Defuzzyfikasi.

# %%
tingkat.input["suhu"] = 15
tingkat.input["orang"] = 10
tingkat.compute()
tingkat.output
# Out:
# OrderedDict([('kipas', 45.43882646691636), ('exhaust', 31.83892182921012)])

# %% [markdown]
# Plotting fungsi keangggotaan Kipas setelah dimasukkan input nilai pada Kipas

# %%
kipas.view(sim=tingkat)

# %% [markdown]
# Plotting fungsi keangggotaan Exhaust setelah dimasukkan input nilai pada Exhaust

# %%
exhaust.view(sim=tingkat)

# %% [markdown]
# ## Perhitungan Manual

# %% [markdown]
# Suhu = 15

# %% [markdown]
# - Suhu Dingin
# $$ Suhu Dingin [x] =
# \begin{cases}
#     \frac{(10-x)}{(10-1)} & ; 1 <  x \leq\ 10 \\
#     0 & ; x \geq 10
# \end{cases}
# $$
#
# - Suhu Sejuk
# $$ Suhu Sejuk [x] =
# \begin{cases}
#     0 & ; x \leq 1\\
#     \frac{(x-1)}{(10-1)} & ;1 < x \leq\ 10 \\
#     \frac{(20-x)}{(20-10)} & ; 10 \leq  x < \ 20 \checkmark\\
#     0 & ; x \geq 20
# \end{cases}
# $$
#
# - Suhu Normal
# $$ Suhu Normal [x] =
# \begin{cases}
#     0 & ; x \leq 10\\
#     \frac{(x-10)}{(20-10)} & ;10 < x \leq\ 20 \checkmark\\
#     \frac{(30-x)}{(30-20)} & ; 20 \leq  x < \ 30 \\
#     0 & ; x \geq 30
# \end{cases}
# $$
#
# - Suhu Hangat
# $$ Suhu Hangat [x] =
# \begin{cases}
#     0 & ; x \leq 20\\
#     \frac{(x-20)}{(30-20)} & ;20 < x \leq\ 30 \\
#     \frac{(40-x)}{(40-30)} & ; 30 \leq  x <\ 40 \\
#     0 & ; x \geq 30
# \end{cases}
# $$
#
# - Suhu Panas
# $$ Suhu Panas [x] =
# \begin{cases}
#     \frac{(x-30)}{(40-30)} & ; 30 <  x \leq\ 40 \\
#     0 & ; x \geq 40
# \end{cases}
# $$

# %% [markdown]
# \begin{equation}
#     \mu SuhuSejuk(15) = (C - X) / (C - B) \\
#     \mu SuhuSejuk(15) = (20 - 15) / (20 - 15) \\
#     \mu SuhuSejuk(15) = 5/10 \\
#     \mu SuhuSejuk(15) = 0.5 \\
#     \mu SuhuNormal(15) = (X - A) / (B-A) \\
#     \mu SuhuNormal(15) = (15 - 10) / (20-10) \\
#     \mu SuhuNormal(15) = 1/2 \\
#     \mu SuhuNormal(15) = 0.5 \\
# \end{equation}

# %% [markdown]
# Orang = 10

# %% [markdown]
# - Orang Sedikit
# $$ Orang Sedikit [x] =
# \begin{cases}
#     \frac{(35-x)}{(35-20)} & ; x \leq\ 35 \checkmark\\
# \end{cases}
# $$
#
# - Orang Sedang
# $$ Orang Sedang [x] =
# \begin{cases}
#     0 & ; x \leq 20\\
#     \frac{(x-20)}{(35-20)} & ;20 < x \leq\ 35 \\
#     \frac{(50-x)}{(50-35)} & ; 35 \leq  x <\ 50 \\
#     0 & ; x \geq 50
# \end{cases}
# $$
#
# - Orang Banyak
# $$ Orang banyak [x] =
# \begin{cases}
#     \frac{(x-30)}{(60-30)} & ; 30 <  x \leq\ 60 \\
# \end{cases}
# $$

# %% [markdown]
# \begin{equation}
#  \mu OrangSedikit(x) = 1
# \end{equation}

# %% [markdown]
# ======================================================================================================
#
# Lalu kita cari nilai z untuk setiap aturan dengan menggunakan fungsi MIN karena menggunakan rule AND
#
# Rule 4 : IF Suhu Sejuk AND Orang Sedikit THEN Kipas Lambat dan Exhaust Pelan
#
# Mencari Nilai Rule
#
#     Rule4 = IF Suhu "Sejuk" dan Orang "Sedikit" Then Kipas "Lambat" dan Exhaust "Pelan"
#           = SuhuSejuk[0,5] dan OrangSedikit[1]
#           = 0.5
#
# Akan diambil nilai terkecil/MIN
#
# Maka nilai yang ada di Rule 4 = 0,5
#
# ======================================================================================================
#
# Rule 7 : IF Suhu Normal AND Orang Sedikit THEN Kipas Cepat dan Exhaust Sedang
#
# Mencari Nilai Rule
#
#     Rule7 = IF Suhu "Normal" dan Orang "Sedikit" Then Kipas "Cepat" dan Exhaust "Sedang"
#           = SuhuNormal[0,5] dan OrangSedikit[1]
#           = 0.5
#
# Akan diambil nilai terkecil/MIN
#
# Maka nilai yang ada di Rule 7 = 0,5
#
# ======================================================================================================

# %% [markdown]
# ![peper.PNG](attachment:peper.PNG)

# %% [markdown]
#     Penghitungan manual pada Kipas
#     X merupakan nilai yang ada pada output kipas yang sudah di pecah menjadi 5 bagian
#     X1 : a:1 b:13
#     X2 : a:13 b:38
#     X3 : a:38 b:50
#     X4 : a:50 b:60
#     X5 : a:60 b:80
#     X6 : a:80 b:90

# %% [markdown]
# $$
#         X1 = 1+\frac{2}{3} x (13-1)\\
#            = 1+8\\
#            = 9\\
# $$
# $$
#         X2 = \frac{1}{2} x (13+38)\\
#            = \frac{1}{2} x 51\\
#            = 25,5\\
# $$
# $$
#         X3 = 38+\frac{1}{3} x (50-38)\\
#            = 38+ 4\\
#            = 42\\
# $$
# $$
#         X4 = 50+\frac{2}{3} x (60-50)\\
#            = 50+\frac{2}{3} x 10\\
#            = \frac{170}{3}\\
# $$
# $$
#         X5 = \frac{1}{2} x (60+80)\\
#            = \frac{1}{2} x 140\\
#            = 70\\
# $$
# $$
#         X6 = 80+\frac{1}{3} x (90-80)\\
#            = 80+\frac{1}{3} x 10\\
#            = \frac{170}{3}\\
# $$
#
# ======================================================================================================

# %% [markdown]
#     Kemudian mencari nilai Luas pada masing-masing daerah
#     A = nilai daerah
#     A1 : Lebar  :13
#          Tinggi :0,5
#     A2 : Panjang:26
#          Lebar  :0,5
#     A3 : Lebar  :13
#          Tinggi :0,5
#     A4 : Lebar  :11
#          Tinggi :0,5
#     A5 : Panjang:21
#          Lebar  :0,5
#     A6 : Lebar  :11
#          Tinggi :0,5

# %% [markdown]
# $$
#         A1 = \frac{1}{2} x (12x0,5)\\
#            = \frac{1}{2} x 6\\
#            = 3\\
# $$
# $$
#         A2 = (27x0,5)\\
#            = 13,5\\
# $$
# $$
#         A3 = \frac{1}{2} x (13x0,5)\\
#            = \frac{1}{2} x 6,5\\
#            = 3,25\\
# $$
# $$
#         A4 = \frac{1}{2} x (11x0,5)\\
#            = \frac{1}{2} x 5,5\\
#            = 2,75\\
# $$
# $$
#         A5 = (21x0,5)\\
#            = 10,5\\
# $$
# $$
#         A6 = \frac{1}{2} x (11x0,5)\\
#            = \frac{1}{2} x 5,5\\
#            = 2,75\\
# $$
#
# ======================================================================================================

# %% [markdown]
# Disini kita mencari nilai X Kipas

# %% [markdown]
#  $$X = \frac{(9x3,25) + (25,5x13) + (42x3,25) + (\frac{170}{3}x2,75) + (70x10,5) + (\frac{250}{3}x2,75)}{3,25+13+3,25+2,75+10,5+2,75} $$
#
#  $$ X = \frac{29.25 + 331,5 + 136,5 + \frac{935}{6} + 735 + \frac{1375}{6}}{35.5} $$
#  $$ X = \frac{1617,25}{35,5} $$
#  $$ X = 45,55633803 $$

# %% [markdown]
#     Hasil output yang dikeluarkan menggunakan code python sebesar 45.43882646691636 sedangkan perhitungan manual sebesar 4.55633803.
#     Terdapat perbedaan sebesar 0.1175115631
#
# ======================================================================================================

# %% [markdown]
# ![peper2.PNG](attachment:peper2.PNG)

# %% [markdown]
#     Penghitungan manual pada Exhexut
#     X merupakan nilai yang ada pada output Exhexut yang sudah di pecah menjadi 5 bagian
#     X1 : a:1 b:13
#     X2 : a:13 b:38
#     X3 : a:38 b:50
#     X4 : a:40 b:45
#     X5 : a:45 b:55
#     X6 : a:55 b:60

# %% [markdown]
# $$
#         X1 = 1+\frac{2}{3} x (13-1)\\
#            = 1+8\\
#            = 9\\
# $$
# $$
#         X2 = \frac{1}{2} x (13+38)\\
#            = \frac{1}{2} x 51\\
#            = 25,5\\
# $$
# $$
#         X3 = 38+\frac{1}{3} x (50-30)\\
#            = 38+4\\
#            = 42\\
# $$
# $$
#         X4 = 40+\frac{2}{3} x (45-40)\\
#            = 50+\frac{10}{3}\\
#            = 43,333\\
# $$
# $$
#         X5 = \frac{1}{2} x (45+55)\\
#            = \frac{1}{2} x 50\\
#            = 50\\
# $$
# $$
#         X6 = 50+\frac{1}{3} x (60-55)\\
#            = 50+\frac{5}{3}\\
#            = 56,666\\
# $$
#
# ======================================================================================================

# %% [markdown]
#     Kemudian mencari nilai Luas pada masing-masing daerah
#     A = nilai daerah
#     A1 : Lebar  :13
#          Tinggi :0,5
#     A2 : Panjang:26
#          Lebar  :0,5
#     A3 : Lebar  :13
#          Tinggi :0,5
#     A4 : Lebar  :6
#          Tinggi :0,5
#     A5 : Panjang:11
#          Lebar  :0,5
#     A6 : Lebar  :6
#          Tinggi :0,5

# %% [markdown]
# $$
#         A1 = \frac{1}{2} x (13x0,5)\\
#            = \frac{1}{2} x 6,5\\
#            = 3,25\\
# $$
# $$
#         A2 = (26x0,5)\\
#            = 13\\
# $$
# $$
#         A3 = \frac{1}{2} x (13x0,5)\\
#            = \frac{1}{2} x 6,5\\
#            = 3,25\\
# $$
# $$
#         A4 = \frac{1}{2} x (6x0,5)\\
#            = \frac{1}{2} x 3\\
#            = 1,5\\
# $$
# $$
#         A5 = (11x0,5)\\
#            = 5,5\\
# $$
# $$
#         A6 = \frac{1}{2} x (6x0,5)\\
#            = \frac{1}{2} x 3\\
#            = 1,5\\
# $$
#
# ======================================================================================================

# %% [markdown]
# Kemudia mencari nilai X Exhsaut

# %% [markdown]
#  $$X = \frac{(9x3,25) + (25,5x13) + (42x3,25) + (43,333x1,5) + (50x5,5) + (56,666x1,5)}{3,25+13+3,25+1,5+5,5+1,5} $$
#
#  $$ X = \frac{29.25 + 331,5 + 136,5 + 65 + 275 + 85}{28} $$
#  $$ X = \frac{922,25}{28} $$
#  $$ X = 32,9375 $$

# %% [markdown]
#  Hasil output yang dikeluarkan menggunakan code python sebesar 31.83892182921012 sedangkan perhitungan manual sebesar 32.9375.
#     Terdapat perbedaan sebesar 1.098578171

# %% [markdown]
# ## Referensi
#
# Aplikasi Fuzzy Logic Pada Pengaturan Air Cooler Untuk Ruangan
#
# Riris Eka Lestari, Agus Maman Abadi Fakultas Matematika dan Ilmu Pengetahuan Alam, Universitas Negeri Yogyakarta Email: ririsekalestari@ymail.com
