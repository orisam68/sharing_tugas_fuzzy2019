# %% [markdown]
# ## Fuzzy Inference System (FIS) dengan Metode Tsukamoto dan Mamdani dalam Menentukan Kelayakan Gaji Karyawan

# %% [markdown]
# Logika Fuzzy adalah metodologi sistem kontrol pemecahan masalah, yang cocok untuk diimplementasikan pada sistem, mulai dari sistem sederhana sampai sistem rumit.

# %%
#memanggil library yang akan kita gunakan
#skfuzzy adalah library fuzzy logic pada python yang bekerja dengan numpy array
import skfuzzy as fz #import library fuzzy gunakan fuzz untuk menggunkaan library ini
from skfuzzy import control as ctrl #panggil library control dari skfuzzy gunakan ctr untuk menggunakan library ini
import numpy as np #import numpy gunkan np untuk menggunakan library ini

# %% [markdown]
# ##### 1. FUZZYFIKASI

# %% [markdown]
# Berikut adalah persamaan garis pada input :Variabel Kemampuan Diri
#
# Kemampuan Diri[Kurang] =  1 = X ≤ 60; (75 - x) / (75 - 60); 60 ≤ x ≤ 75;  0 = x ≥ 75
#
# Kemampuan Diri[Cukup] =  1 = X = 75; (x - 60) / (75 - 60) & (90-x) / (90-75); 60 ≤  x ≤ 75, 75 ≤ x ≤ 90, 0 = x ≥ 90, x ≤ 60
#
# Kemampuan Diri[Baik] =  0 = X ≤ 75; (x - 75) / (90 - 75); 75 ≤ x ≤ 90; 1 = x ≥ 90
#
# $Kemampuan Diri [Kurang] =
# \left\{
#     \begin{array}{ll}
#        1 & \mbox{; } x \leq 60 \\
#        {75-x \over 75-60} & \mbox{; } 60 ≤ x ≤ 75 \\
#        0 & \mbox{; } x \geq 75
#     \end{array}
# \right\}$
# $Kemampuan Diri [Cukup] =
# \left\{
#     \begin{array}{ll}
#        1 & \mbox{; } x = 75 \\
#        {(x-60)/(75-60) \over (90-x)/(90-75)} & \mbox{; } 61 ≤ x ≤ 75, 75≤ x ≤ 90\\
#        0 & \mbox{; } x \geq 90, x \leq 60
#     \end{array}
# \right\}$
# $Kemampuan Diri [Baik] =
# \left\{
#     \begin{array}{ll}
#        0 & \mbox{; } x \leq 75 \\
#        {x-75 \over 90-75} & \mbox{; } 75 ≤ x ≤ 90 \\
#        1 & \mbox{; } x \geq 90
#     \end{array}
# \right\}$
#
#
# Berikut adalah persamaan garis pada input :Variabel Pengembangan Diri
#
# Pengembangan Diri[Kurang] =  1 = X ≤ 60; (75 - x) / (75 - 60); 60 ≤ x ≤ 75;  0 = x ≥ 75
#
# Pengembangan Diri[Cukup] =  1 = X = 75; (x - 60) / (75 - 60) & (90-x) / (90-75); 60 ≤  x ≤ 75, 75 ≤ x ≤ 90, 0 = x ≥ 90, x ≤ 60
#
# Pengembangan Diri[Baik] =  0 = X ≤ 75; (x - 75) / (90 - 75); 75 ≤ x ≤ 90; 1 = x ≥ 90
#
# $Pengembangan Diri [Kurang] =
# \left\{
#     \begin{array}{ll}
#        1 & \mbox{; } x \leq 60 \\
#        {75-x \over 75-60} & \mbox{; } 60 ≤ x ≤ 75 \\
#        0 & \mbox{; } x \geq 75
#     \end{array}
# \right\}$
# $Pengembangan Diri [Cukup] =
# \left\{
#     \begin{array}{ll}
#        1 & \mbox{; } x = 75 \\
#        {(x-60)/(75-60) \over (90-x)/(90-75)} & \mbox{; } 61 ≤ x ≤ 75, 75≤ x ≤ 90\\
#        0 & \mbox{; } x \geq 90, x \leq 60
#     \end{array}
# \right\}$
# $Pengembangan Diri [Baik] =
# \left\{
#     \begin{array}{ll}
#        0 & \mbox{; } x \leq 75 \\
#        {x-75 \over 90-75} & \mbox{; } 75 ≤ x ≤ 90 \\
#        1 & \mbox{; } x \geq 90
#     \end{array}
# \right\}$
#
# Berikut adalah persamaan garis pada input :Variabel Kepribadian
#
# Kepribadian[Kurang] =  1 = X ≤ 60; (75 - x) / (75 - 60); 60 ≤ x ≤ 75;  0 = x ≥ 75
#
# Kepribadian[Cukup] =  1 = X = 75; (x - 60) / (75 - 60) & (90-x) / (90-75); 60 ≤  x ≤ 75, 75 ≤ x ≤ 90, 0 = x ≥ 90, x ≤ 60
#
# Kepribadian[Baik] =  0 = X ≤ 75; (x - 75) / (90 - 75); 75 ≤ x ≤ 90; 1 = x ≥ 90
#
# $Kepribadian [Kurang] =
# \left\{
#     \begin{array}{ll}
#        1 & \mbox{; } x \leq 60 \\
#        {75-x \over 75-60} & \mbox{; } 60 ≤ x ≤ 75 \\
#        0 & \mbox{; } x \geq 75
#     \end{array}
# \right\}$ \\
#
# $Kepribadian [Cukup] =
# \left\{
#     \begin{array}{ll}
#        1 & \mbox{; } x = 75 \\
#        {(x-60)/(75-60) \over (90-x)/(90-75)} & \mbox{; } 61 ≤ x ≤ 75, 75≤ x ≤ 90\\
#        0 & \mbox{; } x \geq 90, x \leq 60
#     \end{array}
# \right\}$ \\
#
# $Kepribadian [Baik] =
# \left\{
#     \begin{array}{ll}
#        0 & \mbox{; } x \leq 75 \\
#        {x-75 \over 90-75} & \mbox{; } 75 ≤ x ≤ 90 \\
#        1 & \mbox{; } x \geq 90
#     \end{array}
# \right\}$

# %%
KD = ctrl.Antecedent(np.arange(0,100,1),'Kemampuan Diri') #variabel Kemampuan Diri dg nilai 0 sampai 100 dengan range 1,Antecedent adalah library untuk 'Input'
PD = ctrl.Antecedent(np.arange(0,100,1),'Pengembangan Diri') #variabel Pengembangan Diri dg nilai 0 sampai 100 dengan range 1,Antecedent adalah library untuk 'Input'
KP = ctrl.Antecedent(np.arange(0,100,1),'Kepribadian') #variabel Kepribadian dg nilai 0 sampai 100 dengan range 1,Antecedent adalah library untuk 'Input'
KL = ctrl.Consequent(np.arange(0,100,1),'Kelayakan') #variabel Kelayakan dg nilai 0 sampai 100 dengan range 1,Consequent adalah library untuk 'Output'

# %% [markdown]
# # Variabel Input

# %% [markdown]
# Berikut adalah persamaan garis pada input :Variabel Kemampuan Diri
#
# Kemampuan Diri[Kurang] =  1 = X ≤ 60; (75 - x) / (75 - 60); 60 ≤ x ≤ 75;  0 = x ≥ 75
#
# Kemampuan Diri[Cukup] =  1 = X = 75; (x - 60) / (75 - 60) & (90-x) / (90-75); 60 ≤  x ≤ 75, 75 ≤ x ≤ 90, 0 = x ≥ 90, x ≤ 60
#
# Kemampuan Diri[Baik] =  0 = X ≤ 75; (x - 75) / (90 - 75); 75 ≤ x ≤ 90; 1 = x ≥ 90 \\
#
#
# $Kemampuan Diri [Kurang] =
# \left\{
#     \begin{array}{ll}
#        1 & \mbox{; } x \leq 60 \\
#        {75-x \over 75-60} & \mbox{; } 60 ≤ x ≤ 75 \\
#        0 & \mbox{; } x \geq 75
#     \end{array}
# \right\}$ \\
#
# $Kemampuan Diri [Cukup] =
# \left\{
#     \begin{array}{ll}
#        1 & \mbox{; } x = 75 \\
#        {(x-60)/(75-60) \over (90-x)/(90-75)} & \mbox{; } 61 ≤ x ≤ 75, 75≤ x ≤ 90\\
#        0 & \mbox{; } x \geq 90, x \leq 60
#     \end{array}
# \right\}$ \
#
# $Kemampuan Diri [Baik] =
# \left\{
#     \begin{array}{ll}
#        0 & \mbox{; } x \leq 75 \\
#        {x-75 \over 90-75} & \mbox{; } 75 ≤ x ≤ 90 \\
#        1 & \mbox{; } x \geq 90
#     \end{array}
# \right\}$

# %%
KD['Kurang']=fz.trapmf(KD.universe,[0,0,60,75]) #membership function Kurang, dalam bentuk trapesium dengan nilai 0 - 75
KD['Cukup']=fz.trimf(KD.universe,[60,75,90]) #membership function Cukup, dalam bentuk segitiga dengan nilai 60 - 90
KD['Baik']=fz.trapmf(KD.universe,[75,90,100,100]) #membership function Baik, dalam bentuk trapesium dengan nilai 75 - 100
KD.view() #menampilkan grafik variabel Kemampuan Diri
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# Berikut adalah persamaan garis pada input :Variabel Pengembangan Diri
#
# Pengembangan Diri[Kurang] =  1 = X ≤ 60; (75 - x) / (75 - 60); 60 ≤ x ≤ 75;  0 = x ≥ 75
#
# Pengembangan Diri[Cukup] =  1 = X = 75; (x - 60) / (75 - 60) & (90-x) / (90-75); 60 ≤  x ≤ 75, 75 ≤ x ≤ 90, 0 = x ≥ 90, x ≤ 60
#
# Pengembangan Diri[Baik] =  0 = X ≤ 75; (x - 75) / (90 - 75); 75 ≤ x ≤ 90; 1 = x ≥ 90 \\
#
# $Pengembangan Diri [Kurang] =
# \left\{
#     \begin{array}{ll}
#        1 & \mbox{; } x \leq 60 \\
#        {75-x \over 75-60} & \mbox{; } 60 ≤ x ≤ 75 \\
#        0 & \mbox{; } x \geq 75
#     \end{array}
# \right\}$ \\
#
# $Pengembangan Diri [Cukup] =
# \left\{
#     \begin{array}{ll}
#        1 & \mbox{; } x = 75 \\
#        {(x-60)/(75-60) \over (90-x)/(90-75)} & \mbox{; } 61 ≤ x ≤ 75, 75≤ x ≤ 90\\
#        0 & \mbox{; } x \geq 90, x \leq 60
#     \end{array}
# \right\}$ \\
#
# $Pengembangan Diri [Baik] =
# \left\{
#     \begin{array}{ll}
#        0 & \mbox{; } x \leq 75 \\
#        {x-75 \over 90-75} & \mbox{; } 75 ≤ x ≤ 90 \\
#        1 & \mbox{; } x \geq 90
#     \end{array}
# \right\}$

# %%
PD['Kurang']=fz.trapmf(PD.universe,[0,0,60,75]) #membership function Kurang, dalam bentuk trapesium dengan nilai 0 - 75
PD['Cukup']=fz.trimf(PD.universe,[60,75,90]) #membership function Cukup, dalam bentuk segitiga dengan nilai 60 - 90
PD['Baik']=fz.trapmf(PD.universe,[75,90,100,100]) #membership function Baik, dalam bentuk trapesium dengan nilai 75 - 100
PD.view() #menampilkan grafik variabel Pengembangan Diri
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# Berikut adalah persamaan garis pada input :Variabel Kepribadian
#
# Kepribadian[Kurang] =  1 = X ≤ 60; (75 - x) / (75 - 60); 60 ≤ x ≤ 75;  0 = x ≥ 75
#
# Kepribadian[Cukup] =  1 = X = 75; (x - 60) / (75 - 60) & (90-x) / (90-75); 60 ≤  x ≤ 75, 75 ≤ x ≤ 90, 0 = x ≥ 90, x ≤ 60
#
# Kepribadian[Baik] =  0 = X ≤ 75; (x - 75) / (90 - 75); 75 ≤ x ≤ 90; 1 = x ≥ 90
#
# $Kepribadian [Kurang] =
# \left\{
#     \begin{array}{ll}
#        1 & \mbox{; } x \leq 60 \\
#        {75-x \over 75-60} & \mbox{; } 60 ≤ x ≤ 75 \\
#        0 & \mbox{; } x \geq 75
#     \end{array}
# \right\}$ \\
#
# $Kepribadian [Cukup] =
# \left\{
#     \begin{array}{ll}
#        1 & \mbox{; } x = 75 \\
#        {(x-60)/(75-60) \over (90-x)/(90-75)} & \mbox{; } 61 ≤ x ≤ 75, 75≤ x ≤ 90\\
#        0 & \mbox{; } x \geq 90, x \leq 60
#     \end{array}
# \right\}$ \\
#
# $Kepribadian [Baik] =
# \left\{
#     \begin{array}{ll}
#        0 & \mbox{; } x \leq 75 \\
#        {x-75 \over 90-75} & \mbox{; } 75 ≤ x ≤ 90 \\
#        1 & \mbox{; } x \geq 90
#     \end{array}
# \right\}$

# %%
KP['Kurang']=fz.trapmf(KP.universe,[0,0,60,75]) #membership function Kurang, dalam bentuk trapesium dengan nilai 0 - 75
KP['Cukup']=fz.trimf(KP.universe,[60,75,90]) #membership function Cukup, dalam bentuk segitiga dengan nilai 60 - 90
KP['Baik']=fz.trapmf(KP.universe,[75,90,100,100]) #membership function Baik, dalam bentuk trapesium dengan nilai 75 - 100
KP.view() #menampilkan grafik variabel Kepribadian
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# # Variabel Output

# %% [markdown]
# Berikut adalah persamaan garis pada output :Variabel Kelayakan
#
# Kelayakan[Tidak Layak] =  1 = X ≤ 60; (75 - x) / (75 - 60); 60 ≤ x ≤ 75;  0 = x ≥ 75
#
# Kelayakan[Cukup Layak] =  1 = X = 75; (x - 60) / (75 - 60) & (90-x) / (90-75); 60 ≤  x ≤ 75, 75 ≤ x ≤ 90, 0 = x ≥ 90, x ≤ 60
#
# Kelayakan[Sangat Layak] =  0 = X ≤ 75; (x - 75) / (90 - 75); 75 ≤ x ≤ 90; 1 = x ≥ 90 \\
#
#
# $Kelayakan [Tidak Layak] =
# \left\{
#     \begin{array}{ll}
#        1 & \mbox{; } x \leq 60 \\
#        {75-x \over 75-60} & \mbox{; } 60 ≤ x ≤ 75 \\
#        0 & \mbox{; } x \geq 75
#     \end{array}
# \right\}$ \\
#
# $Kelayakan [Cukup Layak] =
# \left\{
#     \begin{array}{ll}
#        1 & \mbox{; } x = 75 \\
#        {(x-60)/(75-60) \over (90-x)/(90-75)} & \mbox{; } 61 ≤ x ≤ 75, 75≤ x ≤ 90\\
#        0 & \mbox{; } x \geq 90, x \leq 60
#     \end{array}
# \right\}$ \
#
# $Kelayakan [Sangat Layak] =
# \left\{
#     \begin{array}{ll}
#        0 & \mbox{; } x \leq 75 \\
#        {x-75 \over 90-75} & \mbox{; } 75 ≤ x ≤ 90 \\
#        1 & \mbox{; } x \geq 90
#     \end{array}
# \right\}$

# %%
KL['Tidak Layak']=fz.trapmf(KL.universe,[0,0,60,75]) #membership function Tidak Layak, dalam bentuk trapesium dengan nilai 0 - 75
KL['Cukup Layak']=fz.trimf(KL.universe,[60,75,90]) #membership function Cukup Layak, dalam bentuk segitiga dengan nilai 60 - 90
KL['Sangat Layak']=fz.trapmf(KL.universe,[75,90,100,100]) #membership function Sangat Layak, dalam bentuk trapesium dengan nilai 75 - 100
KL.view() #menampilkan grafik variabel Kelayakan
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# ##### 2. Rule Based

# %%
Rb1 = ctrl.Rule (KD ['Kurang'] & PD ['Kurang'] & KP ['Kurang'], KL ['Tidak Layak'])
Rb1.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xe710d90>)

# %%
Rb2 = ctrl.Rule (KD ['Kurang'] & PD ['Kurang'] & KP ['Cukup'], KL ['Tidak Layak'])
Rb2.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xe7820d0>)

# %%
Rb3 = ctrl.Rule (KD ['Kurang'] & PD ['Kurang'] & KP ['Baik'], KL ['Tidak Layak'])
Rb3.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xe6b8bf0>)

# %%
Rb4 = ctrl.Rule (KD ['Kurang'] & PD ['Cukup'] & KP ['Kurang'], KL ['Tidak Layak'])
Rb4.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xe654490>)

# %%
Rb5 = ctrl.Rule (KD ['Kurang'] & PD ['Cukup'] & KP ['Cukup'], KL ['Cukup Layak'])
Rb5.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xe6bf130>)

# %%
Rb6 = ctrl.Rule (KD ['Kurang'] & PD ['Cukup'] & KP ['Baik'], KL ['Cukup Layak'])
Rb6.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xe6364d0>)

# %%
Rb7 = ctrl.Rule (KD ['Kurang'] & PD ['Baik'] & KP ['Kurang'], KL ['Tidak Layak'])
Rb7.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xe7e63d0>)

# %%
Rb8 = ctrl.Rule (KD ['Kurang'] & PD ['Baik'] & KP ['Cukup'], KL ['Cukup Layak'])
Rb8.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xe831590>)

# %%
Rb9 = ctrl.Rule (KD ['Kurang'] & PD ['Baik'] & KP ['Baik'], KL ['Sangat Layak'])
Rb9.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xe87e410>)

# %%
Rb10 = ctrl.Rule (KD ['Cukup'] & PD ['Kurang'] & KP ['Kurang'], KL ['Tidak Layak'])
Rb10.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xe831450>)

# %%
Rb11 = ctrl.Rule (KD ['Cukup'] & PD ['Kurang'] & KP ['Cukup'], KL ['Cukup Layak'])
Rb11.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xe915190>)

# %%
Rb12 = ctrl.Rule (KD ['Cukup'] & PD ['Kurang'] & KP ['Baik'], KL ['Cukup Layak'])
Rb12.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xe962150>)

# %%
Rb13 = ctrl.Rule (KD ['Cukup'] & PD ['Cukup'] & KP ['Kurang'], KL ['Cukup Layak'])
Rb13.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xe9ae310>)

# %%
Rb14 = ctrl.Rule (KD ['Cukup'] & PD ['Cukup'] & KP ['Cukup'], KL ['Cukup Layak'])
Rb14.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xe9edc90>)

# %%
Rb15 = ctrl.Rule (KD ['Cukup'] & PD ['Cukup'] & KP ['Baik'], KL ['Cukup Layak'])
Rb15.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xea3c6f0>)

# %%
Rb16 = ctrl.Rule (KD ['Cukup'] & PD ['Baik'] & KP ['Kurang'], KL ['Cukup Layak'])
Rb16.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xea8a490>)

# %%
Rb17 = ctrl.Rule (KD ['Cukup'] & PD ['Baik'] & KP ['Cukup'], KL ['Cukup Layak'])
Rb17.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xead4330>)

# %%
Rb18 = ctrl.Rule (KD ['Cukup'] & PD ['Baik'] & KP ['Baik'], KL ['Sangat Layak'])
Rb18.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xeb1d170>)

# %%
Rb19 = ctrl.Rule (KD ['Baik'] & PD ['Kurang'] & KP ['Kurang'], KL ['Tidak Layak'])
Rb19.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xeb69150>)

# %%
Rb20 = ctrl.Rule (KD ['Baik'] & PD ['Kurang'] & KP ['Cukup'], KL ['Cukup Layak'])
Rb20.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xeba2830>)

# %%
Rb21 = ctrl.Rule (KD ['Baik'] & PD ['Kurang'] & KP ['Baik'], KL ['Sangat Layak'])
Rb21.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xebf8c10>)

# %%
Rb22 = ctrl.Rule (KD ['Baik'] & PD ['Cukup'] & KP ['Kurang'], KL ['Cukup Layak'])
Rb22.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xec42bd0>)

# %%
Rb23 = ctrl.Rule (KD ['Baik'] & PD ['Cukup'] & KP ['Cukup'], KL ['Cukup Layak'])
Rb23.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xec8ed50>)

# %%
Rb24 = ctrl.Rule (KD ['Baik'] & PD ['Cukup'] & KP ['Baik'], KL ['Sangat Layak'])
Rb24.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xecdbe30>)

# %%
Rb25 = ctrl.Rule (KD ['Baik'] & PD ['Baik'] & KP ['Kurang'], KL ['Sangat Layak'])
Rb25.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xed27ab0>)

# %%
Rb26 = ctrl.Rule (KD ['Baik'] & PD ['Baik'] & KP ['Cukup'], KL ['Sangat Layak'])
Rb26.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xed73650>)

# %%
Rb27 = ctrl.Rule (KD ['Baik'] & PD ['Baik'] & KP ['Baik'], KL ['Sangat Layak'])
Rb27.view()

# %%
#membuat kontrol sistem dengan kondisi yang telah dibuat sesuai rule base
Kelayakan1 = ctrl.ControlSystem ([Rb1, Rb2, Rb3, Rb4, Rb5, Rb6, Rb7, Rb8, Rb9, Rb10, 
                                 Rb11, Rb12, Rb13, Rb14, Rb15, Rb16, Rb17, Rb18, Rb19, 
                                 Rb20, Rb21, Rb22, Rb23, Rb24, Rb25, Rb26, Rb27])

# %%
#membuat simulasi kontrol sistem dengan kondisi yang telah dibuat sesuai rule base
Kelayakan = ctrl.ControlSystemSimulation(Kelayakan1)

# %%
#membuat interupsi yang meminta inputan dari keyboard
KD = input('Kemampuan Diri :') #membuat inputan Kemampuan Diri
PD = input('Pengembangan Diri :') #membuat inputan Pengembangan Diri
KP = input('Kepribadian :') #membuat inputan Kepribadian

# %%
Kelayakan.input['Kemampuan Diri'] = float(KD) #mengubah format data Kemampuan Diri menjadi float 
Kelayakan.input['Pengembangan Diri'] = float(PD) #mengubah format data Pengembangan Diri menjadi float
Kelayakan.input['Kepribadian'] = float(KP) #mengubah format data Kepribadian menjadi float 

Kelayakan.compute() #menampilkan hasil

# %%
print (Kelayakan.output['Kelayakan']) #mencetak output Kelayakan berdasarkan kondisi yang telah dibuat
KL.view(sim=Kelayakan)
# Out:
# 33.888888888888886
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
