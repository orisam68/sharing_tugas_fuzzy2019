# %% [markdown]
#         Nama : M. Restu Aji
#         NIM  : 09011281722071

# %% [markdown]
# PENENTUAN HARGA JUAL MOBIL BEKAS DENGAN MEMPERTIMBANGKAN HARGA BARU, HARGA BEKAS, KONDISI MOBIL, DAN HARGA BEKAS PRODUK SEJENIS MERK LAIN MENGGUNAKAN FUZZY LOGIC

# %%
import numpy as np 
import skfuzzy as fuzz
import matplotlib.pyplot as plt
from skfuzzy import control as ctrl

# %%
kondisi = np.arange(75,101,1)
HargaBaru= np.arange(170,201,1)
HargaBerkas= np.arange(125,151,1)
HargaKompetitor = np.arange(115,145,1)

# %% [markdown]
# # Fuzzifikasi

# %%
HargaBaru = ctrl.Antecedent(np.arange(170,201,1), 'HargaBaru')
HargaBekas = ctrl.Antecedent(np.arange(125,151,1), 'HargaBekas')
kondisi = ctrl.Antecedent(np.arange(75,101,1), 'kondisi')
HargaKompetitor = ctrl.Antecedent(np.arange(115,145,1), 'HargaKompetitor')
HargaJual = ctrl.Consequent(np.arange(125,151,1), 'HargaJual')

# %%
HargaBaru ['rendah'] = fuzz.trimf(HargaBaru.universe, [170,170,182])
HargaBaru ['sedang'] = fuzz.trimf(HargaBaru.universe, [173,185,197])
HargaBaru ['tinggi'] = fuzz.trimf(HargaBaru.universe, [187,200,200])

HargaBekas ['rendah'] = fuzz.trimf(HargaBekas.universe, [125, 125, 135])
HargaBekas ['sedang'] = fuzz.trimf(HargaBekas.universe, [127, 137,147])
HargaBekas ['tinggi'] = fuzz.trimf(HargaBekas.universe, [140, 150,150])

kondisi ['acceptable'] = fuzz.trimf(kondisi.universe, [75,75,85])
kondisi ['sedang'] = fuzz.trimf(kondisi.universe, [77,87,97])
kondisi ['bagus'] = fuzz.trimf(kondisi.universe, [90,100,100])

HargaKompetitor ['rendah'] = fuzz.trimf(HargaKompetitor.universe, [115, 115, 127])
HargaKompetitor ['sedang'] = fuzz.trimf(HargaKompetitor.universe, [117, 130,142])
HargaKompetitor ['tinggi'] = fuzz.trimf(HargaKompetitor.universe, [133, 145,145])

HargaJual['rendah'] = fuzz.trimf(HargaJual.universe, [125,125,135])
HargaJual['sedang'] = fuzz.trimf(HargaJual.universe, [127,137,147])
HargaJual['tinggi'] = fuzz.trimf(HargaJual.universe, [140, 150,150])

# %%
kondisi.view()
# Out:
# C:\Users\NOM\Anaconda3\lib\site-packages\matplotlib\figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
HargaBaru.view()
# Out:
# C:\Users\NOM\Anaconda3\lib\site-packages\matplotlib\figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
HargaBekas.view()
# Out:
# C:\Users\NOM\Anaconda3\lib\site-packages\matplotlib\figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
HargaJual.view()
# Out:
# C:\Users\NOM\Anaconda3\lib\site-packages\matplotlib\figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
HargaKompetitor.view()
# Out:
# C:\Users\NOM\Anaconda3\lib\site-packages\matplotlib\figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# # Inferencing

# %%
rule1 = ctrl.Rule(HargaBaru['rendah'] & HargaBekas['rendah'] & kondisi['acceptable'] & HargaKompetitor['rendah'], HargaJual['rendah'])
rule2 = ctrl.Rule(HargaBaru['rendah'] & HargaBekas['rendah'] & kondisi['acceptable'] & HargaKompetitor['tinggi'], HargaJual['rendah'])
rule3 = ctrl.Rule(HargaBaru['rendah'] & HargaBekas['rendah'] & kondisi['sedang'] & HargaKompetitor['sedang'], HargaJual['rendah'])
rule4 = ctrl.Rule(HargaBaru['rendah'] & HargaBekas['rendah'] & kondisi['sedang'] & HargaKompetitor['tinggi'], HargaJual['rendah'])
rule5 = ctrl.Rule(HargaBaru['rendah'] & HargaBekas['rendah'] & kondisi['bagus'] & HargaKompetitor['rendah'], HargaJual['rendah'])
rule6 = ctrl.Rule(HargaBaru['rendah'] & HargaBekas['rendah'] & kondisi['bagus'] & HargaKompetitor['tinggi'], HargaJual['sedang'])
rule7 = ctrl.Rule(HargaBaru['rendah'] & HargaBekas['sedang'] & kondisi['acceptable'] & HargaKompetitor['rendah'], HargaJual['rendah'])
rule8 = ctrl.Rule(HargaBaru['rendah'] & HargaBekas['sedang'] & kondisi['acceptable'] & HargaKompetitor['tinggi'], HargaJual['sedang'])
rule9 = ctrl.Rule(HargaBaru['rendah'] & HargaBekas['sedang'] & kondisi['sedang'] & HargaKompetitor['rendah'], HargaJual['rendah'])
rule10 = ctrl.Rule(HargaBaru['rendah'] & HargaBekas['sedang'] & kondisi['sedang'] & HargaKompetitor['tinggi'], HargaJual['sedang'])


rule11 = ctrl.Rule(HargaBaru['rendah'] & HargaBekas['sedang'] & kondisi['bagus'] & HargaKompetitor['rendah'], HargaJual['sedang'])
rule12 = ctrl.Rule(HargaBaru['rendah'] & HargaBekas['sedang'] & kondisi['bagus'] & HargaKompetitor['tinggi'], HargaJual['sedang'])
rule13 = ctrl.Rule(HargaBaru['rendah'] & HargaBekas['rendah'] & kondisi['acceptable'] & HargaKompetitor['rendah'], HargaJual['rendah'])
rule14 = ctrl.Rule(HargaBaru['rendah'] & HargaBekas['tinggi'] & kondisi['acceptable'] & HargaKompetitor['tinggi'], HargaJual['sedang'])
rule15 = ctrl.Rule(HargaBaru['rendah'] & HargaBekas['tinggi'] & kondisi['sedang'] & HargaKompetitor['rendah'], HargaJual['sedang'])
rule16 = ctrl.Rule(HargaBaru['rendah'] & HargaBekas['tinggi'] & kondisi['sedang'] & HargaKompetitor['tinggi'], HargaJual['sedang'])
rule17 = ctrl.Rule(HargaBaru['rendah'] & HargaBekas['tinggi'] & kondisi['bagus'] & HargaKompetitor['rendah'], HargaJual['sedang'])
rule18 = ctrl.Rule(HargaBaru['rendah'] & HargaBekas['tinggi'] & kondisi['bagus'] & HargaKompetitor['tinggi'], HargaJual['tinggi'])
rule19 = ctrl.Rule(HargaBaru['tinggi'] & HargaBekas['rendah'] & kondisi['acceptable'] & HargaKompetitor['rendah'], HargaJual['rendah'])
rule20 = ctrl.Rule(HargaBaru['tinggi'] & HargaBekas['rendah'] & kondisi['acceptable'] & HargaKompetitor['tinggi'], HargaJual['sedang'])

rule21 = ctrl.Rule(HargaBaru['tinggi'] & HargaBekas['rendah'] & kondisi['sedang'] & HargaKompetitor['rendah'], HargaJual['rendah'])
rule22 = ctrl.Rule(HargaBaru['tinggi'] & HargaBekas['rendah'] & kondisi['sedang'] & HargaKompetitor['tinggi'], HargaJual['tinggi'])
rule23 = ctrl.Rule(HargaBaru['tinggi'] & HargaBekas['rendah'] & kondisi['bagus'] & HargaKompetitor['rendah'], HargaJual['rendah'])
rule24 = ctrl.Rule(HargaBaru['tinggi'] & HargaBekas['rendah'] & kondisi['bagus'] & HargaKompetitor['tinggi'], HargaJual['tinggi'])
rule25 = ctrl.Rule(HargaBaru['tinggi'] & HargaBekas['sedang'] & kondisi['acceptable'] & HargaKompetitor['rendah'], HargaJual['rendah'])
rule26 = ctrl.Rule(HargaBaru['tinggi'] & HargaBekas['sedang'] & kondisi['acceptable'] & HargaKompetitor['tinggi'], HargaJual['sedang'])
rule27 = ctrl.Rule(HargaBaru['tinggi'] & HargaBekas['sedang'] & kondisi['sedang'] & HargaKompetitor['rendah'], HargaJual['sedang'])
rule28 = ctrl.Rule(HargaBaru['tinggi'] & HargaBekas['sedang'] & kondisi['sedang'] & HargaKompetitor['tinggi'], HargaJual['tinggi'])
rule29 = ctrl.Rule(HargaBaru['tinggi'] & HargaBekas['sedang'] & kondisi['bagus'] & HargaKompetitor['rendah'], HargaJual['sedang'])
rule30 = ctrl.Rule(HargaBaru['tinggi'] & HargaBekas['sedang'] & kondisi['bagus'] & HargaKompetitor['tinggi'], HargaJual['tinggi'])
rule31 = ctrl.Rule(HargaBaru['tinggi'] & HargaBekas['tinggi'] & kondisi['acceptable'] & HargaKompetitor['rendah'], HargaJual['sedang'])
rule32 = ctrl.Rule(HargaBaru['tinggi'] & HargaBekas['tinggi'] & kondisi['acceptable'] & HargaKompetitor['tinggi'], HargaJual['sedang'])
rule33 = ctrl.Rule(HargaBaru['tinggi'] & HargaBekas['tinggi'] & kondisi['sedang'] & HargaKompetitor['rendah'], HargaJual['tinggi'])
rule34 = ctrl.Rule(HargaBaru['tinggi'] & HargaBekas['tinggi'] & kondisi['sedang'] & HargaKompetitor['tinggi'], HargaJual['tinggi'])
rule35 = ctrl.Rule(HargaBaru['tinggi'] & HargaBekas['tinggi'] & kondisi['bagus'] & HargaKompetitor['rendah'], HargaJual['tinggi'])
rule36 = ctrl.Rule(HargaBaru['tinggi'] & HargaBekas['tinggi'] & kondisi['bagus'] & HargaKompetitor['tinggi'], HargaJual['tinggi'])



rule1.view()
rule2.view()
rule3.view()
rule4.view()
rule5.view()
rule6.view()
rule7.view()
rule8.view()
rule9.view()
rule10.view()
rule11.view()
rule12.view()
rule13.view()
rule14.view()
rule15.view()
rule16.view()
rule17.view()
rule18.view()
rule19.view()
rule20.view()
rule21.view()
rule22.view()
rule23.view()
rule24.view()
rule25.view()
rule26.view()
rule27.view()
rule28.view()
rule29.view()
rule30.view()
rule31.view()
rule32.view()
rule33.view()
rule34.view()
rule35.view()
rule36.view()
# Out:
# C:\Users\NOM\Anaconda3\lib\site-packages\matplotlib\pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xca8c87cc18>)

# %% [markdown]
# # Rule Evaluation

# %%
agregat_rule = ctrl.ControlSystem([rule1, rule2, rule3, 
                                   rule4, rule5, rule6, rule7, rule8, rule9, rule10, rule11, 
                                   rule12, rule13, rule14, rule15, rule16, rule17, rule18, rule19, 
                                   rule20, rule21, rule22, rule23, rule24, rule25, rule26, rule27, 
                                   rule28, rule29, rule30, rule31, rule32, rule33, rule34, rule35, rule36])

# %% [markdown]
# # Defuzzifikasi

# %%
Harga_Jual = ctrl.ControlSystemSimulation(agregat_rule)

# %%
Harga_Jual.input["HargaBaru"] = 175
Harga_Jual.input["HargaBekas"] = 125
Harga_Jual.input["kondisi"] = 80
Harga_Jual.input["HargaKompetitor"] = 120

# %%
Harga_Jual.compute()
Harga_Jual.output
# Out:
# OrderedDict([('HargaJual', 128.88888888888889)])

# %%
HargaJual.view(sim=Harga_Jual)
# Out:
# C:\Users\NOM\Anaconda3\lib\site-packages\matplotlib\figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# # Perhitungan Manual

# %% [markdown]
# \begin{equation}
#     Harga\ Baru = 175 \\
#     Masukkan\,nilai\,suhu\,ke\,dalam\,masing-masing\,fungsi\,keanggotaan\,Harga\,Baru\\
#  \mu ['Rendah'](x) = \begin{cases}
#     1, & \text{$x\leq173$}.\\
#     (182 - x)/(182 - 173) , & \text{$173 \leq x \leq 182$}.\\
#     0, & \text{$x\geq 182$}.\checkmark \\
#   \end{cases}
#   \\
#   \mu['Normal'](x)=\begin{cases}
#     0, & \text{$x\leq 173 $ atau $x\geq197$}.\\
#     (x - 173)/(185 - 173) , & \text{$173 \leq x \leq 185$}.\\
#     (197- x)/(197 - 185) , & \text{$185 \leq x \leq 197$}.\checkmark \\
#   \end{cases}
#   \\
#   \mu ['Tinggi'](x)=\begin{cases}
#     0, & \text{$x\leq 197$}.\\
#     (x - 197)/(197 - 187) , & \text{$187 \leq x \leq 197$}.\\
#     1, & \text{$x\geq 200$}.
#   \end{cases}
# \end{equation}

# %% [markdown]
# \begin{equation}
#     \mu Rendah(175) = (b - x) / (b - a) \\
#     \mu Rendah(175) = (185 - 175) / (185 - 173) \\
#     \mu rendah(175) = 0.833 \\
#     \mu sedang(175) = (x - a) / (b - a) \\
#     \mu sedang(175) = (175 - 173) / (185 - 173) \\
#     \mu sedang(175) = 0.166 \\
# \end{equation}

# %% [markdown]
# \begin{equation}
#     Harga\ Bekas = 125 \\
#     Masukkan\,nilai\,suhu\,ke\,dalam\,masing-masing\,fungsi\,keanggotaan\,Harga\,Bekas\\
#  \mu ['Rendah'](x) = \begin{cases}
#     1, & \text{$x\leq127$}.\\
#     (135 - x)/(135 - 123) , & \text{$127 \leq x \leq 135$}.\\
#     0, & \text{$x\geq 135$}.\checkmark \\
#   \end{cases}
#   \\
#   \mu['Normal'](x)=\begin{cases}
#     0, & \text{$x\leq 127 $ atau $x\geq147$}.\\
#     (x - 127)/(137 - 127) , & \text{$127 \leq x \leq 137$}.\\
#     (147- x)/(147 - 137) , & \text{$137 \leq x \leq 147$}.\\
#   \end{cases}
#   \\
#   \mu ['Tinggi'](x)=\begin{cases}
#     0, & \text{$x\leq 140$}.\\
#     (x - 140)/(147 - 140) , & \text{$140 \leq x \leq 147$}.\\
#     1, & \text{$x\geq 150$}.
#   \end{cases}
# \end{equation}

# %% [markdown]
# \begin{equation}
#     \mu rendah(125) = (b - x) / (b - a) \\
#     \mu rendah(125) = (135 - 125) / (135 - 125) \\
#     \mu rendah(125) = 1 \\
# \end{equation}

# %% [markdown]
# \begin{equation}
#     Kondisi = 80 \\
#     Masukkan\,nilai\,suhu\,ke\,dalam\,masing-masing\,fungsi\,keanggotaan\,Harga\,Bekas\\
#  \mu ['Acceptable'](x) = \begin{cases}
#     1, & \text{$x\leq77$}.\\
#     (85 - x)/(85 - 77) , & \text{$77 \leq x \leq 85$}.\\
#     0, & \text{$x\geq 85$}.\checkmark \\
#   \end{cases}
#   \\
#   \mu['Normal'](x)=\begin{cases}
#     0, & \text{$x\leq 77 $ atau $x\geq97$}.\\
#     (x - 77)/(87 - 77) , & \text{$77 \leq x \leq 87$}.\\
#     (97- x)/(97 - 87) , & \text{$87 \leq x \leq 97$}.\\
#   \end{cases}
#   \\
#   \mu ['Tinggi'](x)=\begin{cases}
#     0, & \text{$x\leq 90$}.\\
#     (x - 90)/(100 - 90) , & \text{$90 \leq x \leq 100$}.\\
#     1, & \text{$x\geq 100$}.
#   \end{cases}
# \end{equation}

# %% [markdown]
# \begin{equation}
#     \mu acceptable(80) = (b - x) / (b - a) \\
#     \mu acceptable(80) = (85 - 80) / (85 - 77) \\
#     \mu acceptable(80) = 0.625 \\
#     \mu sedang(80) = (x - a) / (b - a) \\
#     \mu sedang(80) = (80 - 77) / (87 - 77) \\
#     \mu sedang(80) = 0.3\\
# \end{equation}

# %% [markdown]
# \begin{equation}
#     Harga\ Kompetitor = 120 \\
#     Masukkan\,nilai\,suhu\,ke\,dalam\,masing-masing\,fungsi\,keanggotaan\,Harga\,Kompetitor\\
#  \mu ['Rendah'](x) = \begin{cases}
#     1, & \text{$x\leq117$}.\\
#     (127 - x)/(127 - 117) , & \text{$117 \leq x \leq 127$}.\\
#     0, & \text{$x\geq 127$}.\checkmark \\
#   \end{cases}
#   \\
#   \mu['Normal'](x)=\begin{cases}
#     0, & \text{$x\leq 117 $ atau $x\geq142$}.\\
#     (x - 117)/(130 - 117) , & \text{$117 \leq x \leq 130$}.\\
#     (142 - x)/(142 - 130 ) , & \text{$130 \leq x \leq 142$}.\\
#   \end{cases}
#   \\
#   \mu ['Tinggi'](x)=\begin{cases}
#     0, & \text{$x\leq 133$}.\\
#     (x - 133)/(145 - 133) , & \text{$90 \leq x \leq 100$}.\\
#     1, & \text{$x\geq 145$}.
#   \end{cases}
# \end{equation}

# %% [markdown]
# \begin{equation}
#     \mu rendah(120) = (b - x) / (b - a) \\
#     \mu rendah(120) = (127 - 120) / (127 - 117) \\
#     \mu rendah(120) = 0.7 \\
#     \mu sedang(120) = (x - a) / (b - a) \\
#     \mu sedang(120) = (120 - 117) / (130 - 117) \\
#     \mu sedang(120) = 0.3\\
# \end{equation}

# %% [markdown]
# Mencari nilai terkecil dari evaluasi rule
# 1. IF Harga baru rendah AND Harga Bekas rendah  AND Kondisi rendah AND Kompetitor Rendah THEN Harga Jual Rendah
#
# $$ \\ \alpha(predikat_1) = \mu HargaBaru\ Rendah \cap \mu HargaBekas\ Rendah \cap \mu Kondisi\ acepptible \cap \mu Kompetitor\ rendah$$
# $$\alpha(predikat_1)   = min (\mu HargaBaru[175], \mu HargaBekas[125], \mu Kondisi[80], \mu Kompetitor[120) $$
# $$ \alpha(predikat_1) = min (0.833; 1 ; 0.625 ; 0,7 ) $$
# $$ \alpha(predikat_1) = 0,625 $$

# %% [markdown]
# 2. IF Harga baru rendah AND Harga Bekas rendah  AND Kondisi sedang AND Kompetitor sedang THEN Harga Jual Rendah
#
# $$ \\ \alpha(predikat_1) = \mu HargaBaru\ Rendah \cap \mu HargaBekas\ Rendah \cap \mu Kondisi\ Rendah \cap \mu Kompetitor\ rendah$$
# $$\alpha(predikat_1)   = min (\mu HargaBaru[175], \mu HargaBekas[125], \mu Kondisi[80], \mu Kompetitor[120) $$
# $$ \alpha(predikat_1) = min (0.833; 1 ; 0.3 ; 0,23 ) $$
# $$ \alpha(predikat_1) = 0,23 $$

# %% [markdown]
# Mencari nilai Xi dan Ai untuk output Harga Jual
# Berada Pada Rendah
#
# $$
# X1 = \frac{1}{2} (130 - 0,5) \\
# X1 = 129,75\\
# $$
#
# $$
# X2 = 130 + \frac{1}{3} (135 - 130) \\
# X2 = 131,66 \\
# $$

# %% [markdown]
# $$
# A1 = 5\ x\ 0,5 \\
# A1 = 2,5 \\
# $$

# %% [markdown]
# $$
# A2 = \frac{1}{2}\ (5\ x\ 0.5) \\
# A2 = 1,25 \\
# $$

# %% [markdown]
# $$
# Hasil = \frac{\Sigma\ Xi\ Ai}{Ai}
# $$

# %% [markdown]
# $$
# Hasil = \frac{(129,75\ x\ 2,5)\ +\ (131,66\ x\ 1,25)}{2,5\ +\ 1,25} \\
# Hasil = \frac{ 488,958334}{3,75} \\
# Hasil = 130,3888889
# $$

# %% [markdown]
# Selisih antar perhitungan manual dan perhitungan python = 2,38888889
